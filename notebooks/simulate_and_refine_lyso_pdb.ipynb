# %% [markdown]
# # Generate Simulations

# %%
from orix.crystal_map import Phase
from orix.sampling import get_sample_reduced_fundamental
from diffsims.generators.simulation_generator import SimulationGenerator
from diffpy.structure import Lattice, Structure, Atom
from parse_pdb_with_scale_remove_h import parse_pdb_with_scale

pdbfile = "/home/bubl3932/files/lyso_sim/lyso.pdb"

cell, sg_sym, atoms = parse_pdb_with_scale(pdbfile, remove_hydrogens=True, include_occupancy=True)


# Define the phase using less atoms than in the pdb for computational reasons
# atoms = [Atom("C", (0, 0, 0), 1.0)]

resolution = 10                # angular resolution(granularity) of simulation in degrees
reciprocal_radius = 1/0.6       # 1/Å (i.e. Å⁻¹)
with_direct_beam = False        # Include the direct beam
max_excitation_error = 0.01     # approx 1/thickness of crystal
shape_factor_width = None       # None or float if none then set to max_excitation_error
accelerating_voltage = 300      # kV

# Create the structure and corresponding phase
lattice = Lattice(*cell)
structure = Structure(atoms, lattice)
phase = Phase(space_group = 1, structure=structure)

# Sample orientations in the symmetry-reduced zone (resolution in degrees)
orientations = get_sample_reduced_fundamental(resolution = resolution, point_group=phase.point_group)

# Initialize the simulation generator (e.g., setting the accelerating voltage)
generator = SimulationGenerator(accelerating_voltage = accelerating_voltage, approximate_precession = False)

# Calculate 2D diffraction simulations using the provided phase and orientations
simulations = generator.calculate_diffraction2d(
    phase = phase,
    rotation = orientations,
    reciprocal_radius = reciprocal_radius,
    with_direct_beam = with_direct_beam,
    max_excitation_error = max_excitation_error,
    shape_factor_width = shape_factor_width,
    debye_waller_factors = None,
    show_progressbar = True
)

simulations.plot();
# Out:
# 100%|██████████| 642/642 [00:20<00:00, 31.87it/s]

# %% [markdown]
# # Add Simulations to Image with or without Background

# %%
import os
from tqdm import tqdm
import h5py
from helper_functions_UB import copy_h5_file, get_next_simulation_folder
from compute_B import compute_B

# cell = (11.87250, 11.87250, 11.87250, 90, 90, 90)
in_plane_angle = 180                # set to correspond to geometry file definitions of xs and ss, if p0/corner_x = -512.5 p0/corner_y = -512.5 set to 180
sigma = 2                           # spread of the  in pixels
calibration = 0.002412651978735688  # calculated based on geometry (use script to calculate)
fast = False                        # use fast if no subpixel accuracy is needed
normalize = True                    # normalize the intensities of simulated spots
fast_clip_threshold = 1e-12         # threshold for clipping the fast simulation
intensity_scale = 10000             # scale the intensity of the simulated spots

# Specify the input HDF5 file with background images
input_filename = "/home/bubl3932/files/lyso_sim/642_empty_backgrounds.h5"
# input_filename = "/Users/xiaodong/Desktop/simulations/LTA/4186_empty_backgrounds.h5"

# Compute the B matrix from cell parameters
B = compute_B(cell)

# 1. Create a new simulation folder
base_dir = os.path.dirname(input_filename)
new_sim_folder = get_next_simulation_folder(base_dir)

# 2. Copy the original file to the new simulation folder
output_filename = os.path.join(new_sim_folder, "sim.h5")
copy_h5_file(input_filename, output_filename)

# 3. Process the simulation images.
with h5py.File(output_filename, "r+") as data:
    images = data["entry"]["data"]["images"]
    orientation_matrices = data["entry"]["data"].require_dataset(
        "simulation_orientation_matrices", 
        shape=(images.shape[0], 3, 3), 
        dtype=float
    )
    shape = images.shape[-2:]
    beam_pos = (shape[0] // 2, shape[1] // 2)

    for i in tqdm(range(images.shape[0]), desc="Processing images"):
        img = simulations.irot[i].get_diffraction_pattern(
            shape=shape,
            direct_beam_position=beam_pos,
            in_plane_angle=in_plane_angle,  
            sigma=sigma,
            calibration=calibration,
            fast=fast,
            normalize=normalize,
            fast_clip_threshold=fast_clip_threshold
        )
        img = (img * intensity_scale).astype(images.dtype)
        images[i] += img
        orientation_matrices_i = simulations.rotations[i].to_matrix().squeeze()
        
        orientation_matrices[i] = B @ orientation_matrices_i 
print("Processing complete. Updated file saved at:", output_filename)

# Construct the full file path
simulation_parameter_txt = os.path.join(new_sim_folder, "simulation_parameters.txt")

# Write variables and their values to the file
with open(simulation_parameter_txt, "w") as file:
    file.write(f"cif_file = {pdbfile}\n")
    file.write(f"resolution = {resolution}\n")
    file.write(f"reciprocal_radius = {reciprocal_radius}\n")
    file.write(f"with_direct_beam = {with_direct_beam}\n")
    file.write(f"max_excitation_error = {max_excitation_error}\n")
    file.write(f"shape_factor_width = {shape_factor_width}\n")
    file.write(f"accelerating_voltage = {accelerating_voltage}\n")
    file.write(f"cell = {cell}\n")
    file.write(f"input_filename = {input_filename}\n")
    file.write(f"shape = {shape}\n")
    file.write(f"beam_pos = {beam_pos} (actually 0.5 pixels less i.e use p0/corner_x, p0/corner_y = -{(beam_pos[0] + 0.5, beam_pos[1] + 0.5)} in .geom file)\n")
    file.write(f"sigma = {sigma}\n")
    file.write(f"calibration = {calibration}\n")
    file.write(f"fast = {fast}\n")
    file.write(f"normalize = {normalize}\n")
    file.write(f"fast_clip_threshold = {fast_clip_threshold}\n")
    file.write(f"intensity_scale = {intensity_scale}\n")

print(f"Variables have been written to {simulation_parameter_txt}")

# Read back the entire dataset into memory
with h5py.File(output_filename, "r") as data:
    orientation_matrices_np = data["entry"]["data"]["simulation_orientation_matrices"][:]
output_sol = os.path.join(new_sim_folder, "orientation_matrices.sol")

# Write orientation matrices to a .sol file
with open(output_sol, "w") as sol_file:
    for i, matrix in enumerate(orientation_matrices_np):
        # Flatten the 3x3 matrix (row-major order)
        # Each number is formatted with a sign (+ or -) and 7 decimal places.
        line = " ".join(f"{num:+.7f}" for num in matrix.flatten())
        sol_file.write(f"{output_filename} //{i} " + line + " 0.000 0.000 tP\n")
# Out:
# Processing images: 100%|██████████| 642/642 [00:11<00:00, 57.27it/s]
# Processing complete. Updated file saved at: /home/bubl3932/files/lyso_sim/simulation-5/sim.h5
# Variables have been written to /home/bubl3932/files/lyso_sim/simulation-5/simulation_parameters.txt

# %% [markdown]
# # Show Simulations on Background from .h5 file

# %%
# To make sure plots display inline
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact
from helper_functions_UB import load_h5_data, view_image

# 4. Load the processed data for interactive visualization
images_arr, orientation_matrices_str = load_h5_data(output_filename)

# 5. Set up the interactive viewer
interact(lambda index: view_image(index, images_arr, orientation_matrices_str), 
         index=widgets.IntSlider(min=0, max=images_arr.shape[0]-1, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=641), Output()), _dom_classes=('widget-inter…
# <function __main__.<lambda>(index)>

# %% [markdown]
# # Integration from .sol file

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/home/bubl3932/files/lyso_sim/lyso.geom"
cellfile_path = "/home/bubl3932/files/lyso_sim/lyso.cell"
input_path =   "/home/bubl3932/files/lyso_sim/simulation-1"

output_file_base = "lyso_sim_from_file"

num_threads = 24
x, y = 512.5, 512.5
step_size = 0.5
layers = 0
input_sol_file = "/home/bubl3932/files/lyso_sim/simulation-1/orientation_matrices.sol"

extra_flags=[
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=10",
"--local-bg-radius=5",

# "--peaks=peakfinder8",
# "--threshold=1",
# "--min-snr=1",
# "--min-pix-count=1",
# "--max-pix-count=500",
# "--local-bg-radius=10",
# "--min-res=1",
# "--max-res=800",

# INDEXING
"--indexing=file",
f"--fromfile-input-file={input_sol_file}",
"--no-check-cell",
"--no-check-peaks",
"--no-retry",
"--no-refine",
# INTEGRATION
"--integration=rings",
"--int-radius=4,5,9",
# OUTPUT
"--no-non-hits-in-stream",
"--fix-profile-radius=70000000",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--integration=rings",
"--fix-profile-radius=70000000",
"--int-radius=10,11,15",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /home/bubl3932/files/lyso_sim/simulation-1/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# triclinic P, right handed.
# a      b      c            alpha   beta  gamma
#  26.66  31.15  33.57 A     87.73 108.97 111.60 deg
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Invalid lattice type 'tP'
# Read 642 crystals from /home/bubl3932/files/lyso_sim/simulation-1/orientation_matrices.sol
# List of indexing methods:
#    0: file-nolatt-nocell        (file - no prior information)
# Indexing parameters:
#                   Check unit cell parameters: off
#                         Check peak alignment: off
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: off
# Waiting for the last patterns to be processed...
# Final: 642 images processed, 642 hits (100.0%), 0 indexable (0.0% of hits, 0.0% overall), 0 crystals.
# Processing XY pairs: 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]

# %% [markdown]
# # Index using XGANDALF and Integration using rings

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/home/bubl3932/files/lyso_sim/lyso.geom"
cellfile_path = "/home/bubl3932/files/lyso_sim/lyso.cell"
input_path =   "/home/bubl3932/files/lyso_sim/simulation-1"

output_file_base = "lyso_sim_xgandalf"

num_threads = 24
x, y = 512.5, 512.5
step_size = 0.01
layers = 0
extra_flags=[
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",
"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=3",
"--local-bg-radius=10",
# INDEXING
"--indexing=xgandalf",
"--tolerance=10,10,10,5",
"--no-refine",
"--xgandalf-sampling-pitch=5",
"--xgandalf-grad-desc-iterations=1",
"--xgandalf-tolerance=0.02",
# "--xgandalf-no-deviation-from-provided-cell",
# INTEGRATION
"--integration=rings",
"--int-radius=4,5,9",
"--fix-profile-radius=70000000",
# OUTPUT
"--no-non-hits-in-stream",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--fix-profile-radius=n",
"--fix-divergence=n",
"--integration=rings",
"--int-radius=4,5,10",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /home/bubl3932/files/lyso_sim/simulation-1/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# triclinic P, right handed.
# a      b      c            alpha   beta  gamma
#  26.66  31.15  33.57 A     87.73 108.97 111.60 deg
# List of indexing methods:
#    0: xgandalf-nolatt-cell      (xgandalf using cell parameters as prior information)
# Indexing parameters:
#                   Check unit cell parameters: on
#                         Check peak alignment: on
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: on
# 1 images processed, 1 hits (100.0%), 1 indexable (100.0% of hits, 100.0% overall), 1 crystals, 0.2 images/sec.
# 25 images processed, 25 hits (100.0%), 5 indexable (20.0% of hits, 20.0% overall), 5 crystals, 4.7 images/sec.
# 29 images processed, 29 hits (100.0%), 8 indexable (27.6% of hits, 27.6% overall), 8 crystals, 0.8 images/sec.
# 54 images processed, 54 hits (100.0%), 15 indexable (27.8% of hits, 27.8% overall), 15 crystals, 4.7 images/sec.
# 59 images processed, 59 hits (100.0%), 19 indexable (32.2% of hits, 32.2% overall), 19 crystals, 0.9 images/sec.
# 82 images processed, 82 hits (100.0%), 25 indexable (30.5% of hits, 30.5% overall), 25 crystals, 4.4 images/sec.
# 99 images processed, 99 hits (100.0%), 33 indexable (33.3% of hits, 33.3% overall), 33 crystals, 3.2 images/sec.
# 115 images processed, 115 hits (100.0%), 38 indexable (33.0% of hits, 33.0% overall), 38 crystals, 3.1 images/sec.
# 130 images processed, 130 hits (100.0%), 40 indexable (30.8% of hits, 30.8% overall), 40 crystals, 2.9 images/sec.
# 144 images processed, 144 hits (100.0%), 45 indexable (31.2% of hits, 31.2% overall), 45 crystals, 2.6 images/sec.
# 160 images processed, 160 hits (100.0%), 52 indexable (32.5% of hits, 32.5% overall), 52 crystals, 3.2 images/sec.
# 173 images processed, 173 hits (100.0%), 57 indexable (32.9% of hits, 32.9% overall), 57 crystals, 2.4 images/sec.
# 189 images processed, 189 hits (100.0%), 62 indexable (32.8% of hits, 32.8% overall), 62 crystals, 3.2 images/sec.
# 205 images processed, 205 hits (100.0%), 69 indexable (33.7% of hits, 33.7% overall), 69 crystals, 3.0 images/sec.
# 219 images processed, 219 hits (100.0%), 72 indexable (32.9% of hits, 32.9% overall), 72 crystals, 2.6 images/sec.
# 233 images processed, 233 hits (100.0%), 79 indexable (33.9% of hits, 33.9% overall), 79 crystals, 2.7 images/sec.
# 249 images processed, 249 hits (100.0%), 83 indexable (33.3% of hits, 33.3% overall), 83 crystals, 3.0 images/sec.
# 260 images processed, 260 hits (100.0%), 88 indexable (33.8% of hits, 33.8% overall), 88 crystals, 2.1 images/sec.
# 278 images processed, 278 hits (100.0%), 95 indexable (34.2% of hits, 34.2% overall), 95 crystals, 3.4 images/sec.
# 290 images processed, 290 hits (100.0%), 102 indexable (35.2% of hits, 35.2% overall), 102 crystals, 2.3 images/sec.
# 304 images processed, 304 hits (100.0%), 103 indexable (33.9% of hits, 33.9% overall), 103 crystals, 2.8 images/sec.
# 313 images processed, 313 hits (100.0%), 105 indexable (33.5% of hits, 33.5% overall), 105 crystals, 1.8 images/sec.
# 328 images processed, 328 hits (100.0%), 108 indexable (32.9% of hits, 32.9% overall), 108 crystals, 2.9 images/sec.
# 338 images processed, 338 hits (100.0%), 111 indexable (32.8% of hits, 32.8% overall), 111 crystals, 2.0 images/sec.
# 352 images processed, 352 hits (100.0%), 111 indexable (31.5% of hits, 31.5% overall), 111 crystals, 2.7 images/sec.
# 362 images processed, 362 hits (100.0%), 112 indexable (30.9% of hits, 30.9% overall), 112 crystals, 2.0 images/sec.
# 375 images processed, 375 hits (100.0%), 113 indexable (30.1% of hits, 30.1% overall), 113 crystals, 2.6 images/sec.
# 389 images processed, 389 hits (100.0%), 116 indexable (29.8% of hits, 29.8% overall), 116 crystals, 2.6 images/sec.
# 403 images processed, 403 hits (100.0%), 119 indexable (29.5% of hits, 29.5% overall), 119 crystals, 2.8 images/sec.
# 414 images processed, 414 hits (100.0%), 121 indexable (29.2% of hits, 29.2% overall), 121 crystals, 2.1 images/sec.
# 430 images processed, 430 hits (100.0%), 123 indexable (28.6% of hits, 28.6% overall), 123 crystals, 3.2 images/sec.
# 440 images processed, 440 hits (100.0%), 126 indexable (28.6% of hits, 28.6% overall), 126 crystals, 2.0 images/sec.
# 459 images processed, 459 hits (100.0%), 130 indexable (28.3% of hits, 28.3% overall), 130 crystals, 3.5 images/sec.
# 470 images processed, 470 hits (100.0%), 137 indexable (29.1% of hits, 29.1% overall), 137 crystals, 2.2 images/sec.
# 486 images processed, 486 hits (100.0%), 140 indexable (28.8% of hits, 28.8% overall), 140 crystals, 2.9 images/sec.
# 496 images processed, 496 hits (100.0%), 142 indexable (28.6% of hits, 28.6% overall), 142 crystals, 2.0 images/sec.
# 515 images processed, 515 hits (100.0%), 147 indexable (28.5% of hits, 28.5% overall), 147 crystals, 3.7 images/sec.
# 525 images processed, 525 hits (100.0%), 152 indexable (29.0% of hits, 29.0% overall), 152 crystals, 2.0 images/sec.
# 542 images processed, 542 hits (100.0%), 156 indexable (28.8% of hits, 28.8% overall), 156 crystals, 3.1 images/sec.
# 553 images processed, 553 hits (100.0%), 161 indexable (29.1% of hits, 29.1% overall), 161 crystals, 2.2 images/sec.
# 568 images processed, 568 hits (100.0%), 165 indexable (29.0% of hits, 29.0% overall), 165 crystals, 2.8 images/sec.
# 581 images processed, 581 hits (100.0%), 167 indexable (28.7% of hits, 28.7% overall), 167 crystals, 2.5 images/sec.
# 595 images processed, 595 hits (100.0%), 172 indexable (28.9% of hits, 28.9% overall), 172 crystals, 2.7 images/sec.
# 608 images processed, 608 hits (100.0%), 173 indexable (28.5% of hits, 28.5% overall), 173 crystals, 2.4 images/sec.
# Waiting for the last patterns to be processed...
# 624 images processed, 624 hits (100.0%), 181 indexable (29.0% of hits, 29.0% overall), 181 crystals, 3.2 images/sec.
# 642 images processed, 642 hits (100.0%), 183 indexable (28.5% of hits, 28.5% overall), 183 crystals, 3.4 images/sec.
# Final: 642 images processed, 642 hits (100.0%), 183 indexable (28.5% of hits, 28.5% overall), 183 crystals.
# Processing XY pairs: 100%|██████████| 1/1 [04:09<00:00, 249.30s/it]

# %%
import os 
from run_partialator_and_convert import run_partialator_and_convert
from convert_hkl_crystfel_to_shelx import convert_hkl_crystfel_to_shelx

stream_file = "/home/bubl3932/files/LTA_sim/simulation-41/LTAsim_from_file_-512.5_-512.5.stream"
#"/Users/xiaodong/Desktop/simulations/LTA/simulation-43/LTAsim_from_file_-512.5_-512.5.stream" # Stream file to be merged
pointgroup = "m-3m"  # Point group of the crystal
num_threads = 24
iterations = 5

output_dir = run_partialator_and_convert(
    stream_file,
    pointgroup=pointgroup,
    num_threads=num_threads,
    iterations=iterations,
)

if output_dir is not None:
    print("All done. Results are in:", output_dir)

convert_hkl_crystfel_to_shelx(os.path.join(output_dir, "crystfel.hkl"))
