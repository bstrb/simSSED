# %% [markdown]
# # Generate Simulations

# %%
from orix.crystal_map import Phase
from orix.sampling import get_sample_reduced_fundamental
from diffsims.generators.simulation_generator import SimulationGenerator
from diffpy.structure import Lattice, Structure
from parse_pdb_with_scale_remove_h import parse_pdb_with_scale

pdbfile = "/home/bubl3932/files/lyso_sim/lyso.pdb"

cell, sg_sym, atoms = parse_pdb_with_scale(pdbfile, remove_hydrogens=True, include_occupancy=True)

resolution = 2                # angular resolution(granularity) of simulation in degrees
reciprocal_radius = 1/0.6       # 1/Å (i.e. Å⁻¹)
with_direct_beam = False        # Include the direct beam
max_excitation_error = 0.005     # approx 1/thickness of crystal
shape_factor_width = None       # None or float if none then set to max_excitation_error
accelerating_voltage = 300      # kV

# Create the structure and corresponding phase
lattice = Lattice(*cell)
structure = Structure(atoms, lattice)
phase = Phase(space_group = 1, structure=structure)

# Sample orientations in the symmetry-reduced zone (resolution in degrees)
orientations = get_sample_reduced_fundamental(resolution = resolution, point_group=phase.point_group)

# Initialize the simulation generator (e.g., setting the accelerating voltage)
generator = SimulationGenerator(accelerating_voltage = accelerating_voltage, approximate_precession = False)

# Calculate 2D diffraction simulations using the provided phase and orientations
simulations = generator.calculate_diffraction2d(
    phase = phase,
    rotation = orientations,
    reciprocal_radius = reciprocal_radius,
    with_direct_beam = with_direct_beam,
    max_excitation_error = max_excitation_error,
    shape_factor_width = shape_factor_width,
    debye_waller_factors = None,
    show_progressbar = True
)

simulations.plot();
# Out:
# 100%|██████████| 14442/14442 [03:47<00:00, 63.57it/s]

# %% [markdown]
# # Add Simulations to Image with or without Background

# %%
import os
import numpy as np
from tqdm import tqdm
import h5py
from helper_functions_UB import copy_h5_file, get_next_simulation_folder
from compute_B import compute_B

# cell = (11.87250, 11.87250, 11.87250, 90, 90, 90)
in_plane_angle = 180                # set to correspond to geometry file definitions of xs and ss, if p0/corner_x = -512.5 p0/corner_y = -512.5 set to 180
sigma = 2                           # spread of the  in pixels
calibration = 0.002412651978735688  # calculated based on geometry (use script to calculate)
fast = False                        # use fast if no subpixel accuracy is needed
normalize = True                    # normalize the intensities of simulated spots
fast_clip_threshold = 1e-12         # threshold for clipping the fast simulation
intensity_scale = 10000             # scale the intensity of the simulated spots

# Specify the input HDF5 file with background images
input_filename = "/home/bubl3932/files/lyso_sim/14442_empty_backgrounds.h5"
# input_filename = "/Users/xiaodong/Desktop/simulations/LTA/4186_empty_backgrounds.h5"

# Compute the B matrix from cell parameters
B = compute_B(cell)

# 1. Create a new simulation folder
base_dir = os.path.dirname(input_filename)
new_sim_folder = get_next_simulation_folder(base_dir)

# 2. Copy the original file to the new simulation folder
output_filename = os.path.join(new_sim_folder, "sim.h5")
copy_h5_file(input_filename, output_filename)

# 3. Process the simulation images.
with h5py.File(output_filename, "r+") as data:
    images = data["entry"]["data"]["images"]
    orientation_matrices = data["entry"]["data"].require_dataset(
        "simulation_orientation_matrices", 
        shape=(images.shape[0], 3, 3), 
        dtype=float
    )
    shape = images.shape[-2:]
    beam_pos = (shape[0] // 2, shape[1] // 2)

    for i in tqdm(range(images.shape[0]), desc="Processing images"):
        img = simulations.irot[i].get_diffraction_pattern(
            shape=shape,
            direct_beam_position=beam_pos,
            in_plane_angle=in_plane_angle,  
            sigma=sigma,
            calibration=calibration,
            fast=fast,
            normalize=normalize,
            fast_clip_threshold=fast_clip_threshold
        )
        img = (img * intensity_scale).astype(images.dtype)
        images[i] += img
        orientation_matrices_i = simulations.rotations[i].to_matrix().squeeze()
        
        orientation_matrices[i] = B.T @ orientation_matrices_i 
print("Processing complete. Updated file saved at:", output_filename)

# Construct the full file path
simulation_parameter_txt = os.path.join(new_sim_folder, "simulation_parameters.txt")

# Write variables and their values to the file
with open(simulation_parameter_txt, "w") as file:
    file.write(f"cif_file = {pdbfile}\n")
    file.write(f"resolution = {resolution}\n")
    file.write(f"reciprocal_radius = {reciprocal_radius}\n")
    file.write(f"with_direct_beam = {with_direct_beam}\n")
    file.write(f"max_excitation_error = {max_excitation_error}\n")
    file.write(f"shape_factor_width = {shape_factor_width}\n")
    file.write(f"accelerating_voltage = {accelerating_voltage}\n")
    file.write(f"cell = {cell}\n")
    file.write(f"input_filename = {input_filename}\n")
    file.write(f"shape = {shape}\n")
    file.write(f"beam_pos = {beam_pos} (actually 0.5 pixels less i.e use p0/corner_x, p0/corner_y = -{(beam_pos[0] + 0.5, beam_pos[1] + 0.5)} in .geom file)\n")
    file.write(f"sigma = {sigma}\n")
    file.write(f"calibration = {calibration}\n")
    file.write(f"fast = {fast}\n")
    file.write(f"normalize = {normalize}\n")
    file.write(f"fast_clip_threshold = {fast_clip_threshold}\n")
    file.write(f"intensity_scale = {intensity_scale}\n")

print(f"Variables have been written to {simulation_parameter_txt}")

# Read back the entire dataset into memory
with h5py.File(output_filename, "r") as data:
    orientation_matrices_np = data["entry"]["data"]["simulation_orientation_matrices"][:]
output_sol = os.path.join(new_sim_folder, "orientation_matrices.sol")

# Write orientation matrices to a .sol file
with open(output_sol, "w") as sol_file:
    for i, matrix in enumerate(orientation_matrices_np):
        # Flatten the 3x3 matrix (row-major order)
        # Each number is formatted with a sign (+ or -) and 7 decimal places.
        line = " ".join(f"{num:+.7f}" for num in matrix.flatten())
        sol_file.write(f"{output_filename} //{i} " + line + " 0.000 0.000 aP\n")
# Out:
# Processing images: 100%|██████████| 14442/14442 [08:42<00:00, 27.66it/s]
# Processing complete. Updated file saved at: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5
# Variables have been written to /home/bubl3932/files/lyso_sim/simulation-10/simulation_parameters.txt

# %% [markdown]
# # Show Simulations on Background from .h5 file

# %%
# To make sure plots display inline
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact
from helper_functions_UB import load_h5_data, view_image

# 4. Load the processed data for interactive visualization
images_arr, orientation_matrices_str = load_h5_data(output_filename)

# 5. Set up the interactive viewer
interact(lambda index: view_image(index, images_arr, orientation_matrices_str), 
         index=widgets.IntSlider(min=0, max=images_arr.shape[0]-1, step=1, value=0))

# %% [markdown]
# # Integration from .sol file

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/home/bubl3932/files/lyso_sim/lyso.geom"
cellfile_path = "/home/bubl3932/files/lyso_sim/lyso.cell"
input_path =   "/home/bubl3932/files/lyso_sim/simulation-10"

output_file_base = "lyso_sim_from_file"

num_threads = 24
x, y = 512.5, 512.5
step_size = 0.5
layers = 0
input_sol_file = "/home/bubl3932/files/lyso_sim/simulation-10/orientation_matrices.sol"

extra_flags=[
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=10",
"--local-bg-radius=5",

# "--peaks=peakfinder8",
# "--threshold=1",
# "--min-snr=1",
# "--min-pix-count=1",
# "--max-pix-count=500",
# "--local-bg-radius=10",
# "--min-res=1",
# "--max-res=800",

# INDEXING
"--indexing=file",
f"--fromfile-input-file={input_sol_file}",
"--no-check-cell",
"--no-check-peaks",
"--no-retry",
"--no-refine",
# INTEGRATION
"--integration=rings",
"--int-radius=4,5,9",
# OUTPUT
"--no-non-hits-in-stream",
"--fix-profile-radius=30000000",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--integration=rings",
"--fix-profile-radius=70000000",
"--int-radius=10,11,15",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /home/bubl3932/files/lyso_sim/simulation-10/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# triclinic P, right handed.
# a      b      c            alpha   beta  gamma
#  26.66  31.15  33.57 A     87.73 108.97 111.60 deg
# Read 14442 crystals from /home/bubl3932/files/lyso_sim/simulation-10/orientation_matrices.sol
# List of indexing methods:
#    0: file-nolatt-nocell        (file - no prior information)
# Indexing parameters:
#                   Check unit cell parameters: off
#                         Check peak alignment: off
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: off
# 1008 images processed, 1008 hits (100.0%), 1008 indexable (100.0% of hits, 100.0% overall), 1008 crystals, 201.5 images/sec.
# 2065 images processed, 2065 hits (100.0%), 2065 indexable (100.0% of hits, 100.0% overall), 2065 crystals, 211.4 images/sec.
# 3075 images processed, 3075 hits (100.0%), 3075 indexable (100.0% of hits, 100.0% overall), 3075 crystals, 202.0 images/sec.
# 4082 images processed, 4082 hits (100.0%), 4082 indexable (100.0% of hits, 100.0% overall), 4082 crystals, 201.3 images/sec.
# 5144 images processed, 5144 hits (100.0%), 5144 indexable (100.0% of hits, 100.0% overall), 5144 crystals, 212.4 images/sec.
# 6157 images processed, 6157 hits (100.0%), 6157 indexable (100.0% of hits, 100.0% overall), 6157 crystals, 202.4 images/sec.
# 7178 images processed, 7178 hits (100.0%), 7178 indexable (100.0% of hits, 100.0% overall), 7178 crystals, 204.2 images/sec.
# 8185 images processed, 8185 hits (100.0%), 8185 indexable (100.0% of hits, 100.0% overall), 8185 crystals, 201.0 images/sec.
# 9189 images processed, 9189 hits (100.0%), 9189 indexable (100.0% of hits, 100.0% overall), 9189 crystals, 200.7 images/sec.
# 10207 images processed, 10207 hits (100.0%), 10207 indexable (100.0% of hits, 100.0% overall), 10207 crystals, 203.6 images/sec.
# 11154 images processed, 11154 hits (100.0%), 11154 indexable (100.0% of hits, 100.0% overall), 11154 crystals, 189.4 images/sec.
# 12091 images processed, 12091 hits (100.0%), 12091 indexable (100.0% of hits, 100.0% overall), 12091 crystals, 186.8 images/sec.
# 13061 images processed, 13061 hits (100.0%), 13061 indexable (100.0% of hits, 100.0% overall), 13061 crystals, 193.8 images/sec.
# 14013 images processed, 14013 hits (100.0%), 14013 indexable (100.0% of hits, 100.0% overall), 14013 crystals, 190.4 images/sec.
# Waiting for the last patterns to be processed...
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# Worker 2 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14416 14417
# Task ID was: read_queue
# Worker 19 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14413 14414
# Task ID was: read_queue
# Worker 18 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14419 14420
# Task ID was: read_queue
# Worker 14 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14421 14422
# Task ID was: read_queue
# Worker 4 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14422 14423
# Task ID was: read_queue
# Worker 6 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14424 14425
# Task ID was: read_queue
# Worker 15 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14425 14426
# Task ID was: read_queue
# Worker 7 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14423 14424
# Task ID was: read_queue
# Worker 8 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14426 14427
# Task ID was: read_queue
# Worker 22 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14430 14431
# Task ID was: read_queue
# Worker 13 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14429 14430
# Task ID was: read_queue
# Worker 20 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14432 14433
# Task ID was: read_queue
# Worker 11 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14428 14429
# Task ID was: read_queue
# Worker 1 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14427 14428
# Task ID was: read_queue
# Worker 9 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14431 14432
# Task ID was: read_queue
# Worker 21 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14434 14435
# Task ID was: read_queue
# Worker 17 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14435 14436
# Task ID was: read_queue
# Worker 0 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14433 14434
# Task ID was: read_queue
# Worker 10 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14438 14439
# Task ID was: read_queue
# Worker 5 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14440 14441
# Task ID was: read_queue
# Worker 12 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14441 14442
# Task ID was: read_queue
# Worker 3 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14437 14438
# Task ID was: read_queue
# Worker 23 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14436 14437
# Task ID was: read_queue
# Worker 16 was killed by signal 6
# Event ID was: /home/bubl3932/files/lyso_sim/simulation-10/sim.h5 //14439 14440
# Task ID was: read_queue
# Final: 14442 images processed, 14442 hits (100.0%), 14442 indexable (100.0% of hits, 100.0% overall), 14442 crystals.
# free(): double free detected in tcache 2
# Aborted (core dumped)
# Processing XY pairs: 100%|██████████| 1/1 [01:16<00:00, 76.30s/it]
# Error during indexamajig execution: Command 'indexamajig -g /home/bubl3932/files/lyso_sim/lyso.geom -i /home/bubl3932/files/lyso_sim/simulation-10/list.lst -o /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5.stream -p /home/bubl3932/files/lyso_sim/lyso.cell -j 24 --no-revalidate --no-half-pixel-shift --peaks=peakfinder9 --min-snr=1 --min-snr-biggest-pix=1 --min-sig=10 --local-bg-radius=5 --indexing=file --fromfile-input-file=/home/bubl3932/files/lyso_sim/simulation-10/orientation_matrices.sol --no-check-cell --no-check-peaks --no-retry --no-refine --integration=rings --int-radius=4,5,9 --no-non-hits-in-stream --fix-profile-radius=30000000' returned non-zero exit status 134.

# %% [markdown]
# # Index using XGANDALF and Integration using rings

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/home/bubl3932/files/lyso_sim/lyso.geom"
cellfile_path = "/home/bubl3932/files/lyso_sim/lyso.cell"
input_path =   "/home/bubl3932/files/lyso_sim/simulation-1"

output_file_base = "lyso_sim_xgandalf"

num_threads = 24
x, y = 512.5, 512.5
step_size = 0.01
layers = 0
extra_flags=[
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",
"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=3",
"--local-bg-radius=10",
# INDEXING
"--indexing=xgandalf",
"--tolerance=10,10,10,5",
"--no-refine",
"--xgandalf-sampling-pitch=5",
"--xgandalf-grad-desc-iterations=1",
"--xgandalf-tolerance=0.02",
# "--xgandalf-no-deviation-from-provided-cell",
# INTEGRATION
"--integration=rings",
"--int-radius=4,5,9",
"--fix-profile-radius=70000000",
# OUTPUT
"--no-non-hits-in-stream",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--fix-profile-radius=n",
"--fix-divergence=n",
"--integration=rings",
"--int-radius=4,5,10",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)

# %%
import os 
from run_partialator_and_convert import run_partialator_and_convert
from convert_hkl_crystfel_to_shelx import convert_hkl_crystfel_to_shelx

stream_file = "/home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5.stream"
cell_file = "/home/bubl3932/files/lyso_sim/lyso.cell"
pointgroup = "1"  # Point group of the crystal
num_threads = 24
iterations = 5

output_dir = run_partialator_and_convert(
    stream_file,
    pointgroup=pointgroup,
    num_threads=num_threads,
    iterations=iterations,
    convert_to_mtz=True,
    cell_file=cell_file
)

if output_dir is not None:
    print("All done. Results are in:", output_dir)

# convert_hkl_crystfel_to_shelx(os.path.join(output_dir, "crystfel.hkl"))
# Out:
# Running partialator for stream file: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5.stream
# Partialator Progress: 100%|██████████| 7/7 [08:13<00:00, 70.51s/Residual]
# Partialator completed for stream file: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5.stream
# [INFO] Converting crystfel.hkl to output.mtz in directory: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5_merge_5_iter
# [INFO] Conversion to output.mtz completed successfully in: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5_merge_5_iter
# Conversion to MTZ successful. Output in: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5_merge_5_iter
# All done. Results are in: /home/bubl3932/files/lyso_sim/simulation-10/lyso_sim_from_file_-512.5_-512.5_merge_5_iter
