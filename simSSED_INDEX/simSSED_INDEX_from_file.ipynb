# %% [markdown]
# Indexing using xGandalf (layers = layers of step size )

# %%
from gandalf_iterator import gandalf_iterator

# geomfile_path = "/Users/xiaodong/Desktop/simulations/LTA/LTAsim.geom"
# cellfile_path = "/Users/xiaodong/Desktop/simulations/LTA/LTA.cell"
# input_path =   "/Users/xiaodong/Desktop/simulations/LTA/simulation-17"

geomfile_path = "/home/bubl3932/files/LTA_sim/LTAsim.geom"
cellfile_path = "/home/bubl3932/files/LTA_sim/LTA.cell"
input_path =   "/home/bubl3932/files/LTA_sim/simulation-22"

output_file_base = "LTAsim_from_file"

num_threads = 23
x, y = 512.5, 512.5
step_size = 0.5
layers = 0
input_sol_file = "/home/bubl3932/files/LTA_sim/simulation-22/orientation_matrices.sol"
# input_sol_file = "/Users/xiaodong/Desktop/simulations/LTA/simulation-17/orientation_matrices.sol"

extra_flags=[
# BASIC OPTIONS
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",
"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=3",
"--local-bg-radius=3",
# INDEXING
"--indexing=file",
f"--fromfile-input-file={input_sol_file}",
"--no-check-cell",
"--no-check-peaks",
"--no-retry",
"--no-refine",

# "--indexing=xgandalf",
# "--no-refine",
# "--xgandalf-sampling-pitch=5"
# "--xgandalf-grad-desc-iterations=1"
# "--xgandalf-tolerance=0.02"

# INTEGRATION
"--integration=rings",
"--int-radius=4,5,10",
# OUTPUT
"--no-non-hits-in-stream",
"--fix-profile-radius=38000000",
# "--no-peaks-in-stream",
# "--no-refls-in-stream",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--integration=rings",
"--int-radius=4,5,10",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /home/bubl3932/files/LTA_sim/simulation-22/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# cubic P, right handed.
# a      b      c            alpha   beta  gamma
#  11.87  11.87  11.87 A     90.00  90.00  90.00 deg
# Read 1081 crystals from /home/bubl3932/files/LTA_sim/simulation-22/orientation_matrices.sol
# List of indexing methods:
#    0: file-nolatt-nocell        (file - no prior information)
# Indexing parameters:
#                   Check unit cell parameters: off
#                         Check peak alignment: off
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: off
# Waiting for the last patterns to be processed...
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# double free or corruption (!prev)
# Worker 17 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1053 1054
# Task ID was: read_queue
# Worker 14 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1063 1064
# Task ID was: read_queue
# Worker 22 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1067 1068
# Task ID was: read_queue
# Worker 8 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1066 1067
# Task ID was: read_queue
# Worker 15 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1065 1066
# Task ID was: read_queue
# Worker 12 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1068 1069
# Task ID was: read_queue
# Worker 10 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1062 1063
# Task ID was: read_queue
# Worker 6 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1061 1062
# Task ID was: read_queue
# Worker 4 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1073 1074
# Task ID was: read_queue
# Worker 21 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1060 1061
# Task ID was: read_queue
# Worker 13 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1064 1065
# Task ID was: read_queue
# Worker 18 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1059 1060
# Task ID was: read_queue
# Worker 9 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1072 1073
# Task ID was: read_queue
# Worker 3 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1071 1072
# Task ID was: read_queue
# Worker 5 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1070 1071
# Task ID was: read_queue
# Worker 0 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1074 1075
# Task ID was: read_queue
# Worker 20 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1076 1077
# Task ID was: read_queue
# Worker 7 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1080 1081
# Task ID was: read_queue
# Worker 19 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1077 1078
# Task ID was: read_queue
# Worker 2 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1078 1079
# Task ID was: read_queue
# Worker 1 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1075 1076
# Task ID was: read_queue
# Worker 16 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1069 1070
# Task ID was: read_queue
# Worker 11 was killed by signal 6
# Event ID was: /home/bubl3932/files/LTA_sim/simulation-22/sim.h5 //1079 1080
# Task ID was: read_queue
# Final: 1081 images processed, 1081 hits (100.0%), 1081 indexable (100.0% of hits, 100.0% overall), 1081 crystals.
# free(): double free detected in tcache 2
# Aborted (core dumped)
# Processing XY pairs: 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]
# Error during indexamajig execution: Command 'indexamajig -g /home/bubl3932/files/LTA_sim/LTAsim.geom -i /home/bubl3932/files/LTA_sim/simulation-22/list.lst -o /home/bubl3932/files/LTA_sim/simulation-22/LTAsim_from_file_-512.5_-512.5.stream -p /home/bubl3932/files/LTA_sim/LTA.cell -j 23 --no-revalidate --no-half-pixel-shift --peaks=peakfinder9 --min-snr=1 --min-snr-biggest-pix=1 --min-sig=3 --local-bg-radius=3 --indexing=file --fromfile-input-file=/home/bubl3932/files/LTA_sim/simulation-22/orientation_matrices.sol --no-check-cell --no-check-peaks --no-retry --no-refine --integration=rings --int-radius=4,5,10 --no-non-hits-in-stream --fix-profile-radius=38000000' returned non-zero exit status 134.
