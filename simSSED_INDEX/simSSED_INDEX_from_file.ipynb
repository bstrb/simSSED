# %% [markdown]
# # Integration from file

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/Users/xiaodong/Desktop/simulations/LTA/LTAsim.geom"
cellfile_path = "/Users/xiaodong/Desktop/simulations/LTA/LTA.cell"
input_path =   "/Users/xiaodong/Desktop/simulations/LTA/simulation-29"

# geomfile_path = "/home/bubl3932/files/LTA_sim/LTAsim.geom"
# cellfile_path = "/home/bubl3932/files/LTA_sim/LTA.cell"
# input_path =   "/home/bubl3932/files/LTA_sim/simulation-22"

output_file_base = "LTAsim_from_file"

num_threads = 8
x, y = 512.5, 512.5
step_size = 0.5
layers = 0
# input_sol_file = "/home/bubl3932/files/LTA_sim/simulation-22/orientation_matrices.sol"
input_sol_file = "/Users/xiaodong/Desktop/simulations/LTA/simulation-29/orientation_matrices.sol"

extra_flags=[
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",
"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=3",
"--local-bg-radius=3",
# INDEXING
"--indexing=file",
f"--fromfile-input-file={input_sol_file}",
"--no-check-cell",
"--no-check-peaks",
"--no-retry",
"--no-refine",
# INTEGRATION
"--integration=rings",
"--int-radius=4,5,9",
# OUTPUT
"--no-non-hits-in-stream",
"--fix-profile-radius=70000000",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--integration=rings",
"--int-radius=4,5,10",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /Users/xiaodong/Desktop/simulations/LTA/simulation-29/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# cubic P, right handed.
# a      b      c            alpha   beta  gamma
#  11.87  11.87  11.87 A     90.00  90.00  90.00 deg
# Read 4186 crystals from /Users/xiaodong/Desktop/simulations/LTA/simulation-29/orientation_matrices.sol
# List of indexing methods:
#    0: file-nolatt-nocell        (file - no prior information)
# Indexing parameters:
#                   Check unit cell parameters: off
#                         Check peak alignment: off
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: off
# 721 images processed, 721 hits (100.0%), 721 indexable (100.0% of hits, 100.0% overall), 721 crystals, 144.0 images/sec.
# 1374 images processed, 1374 hits (100.0%), 1374 indexable (100.0% of hits, 100.0% overall), 1374 crystals, 130.5 images/sec.
# 1976 images processed, 1976 hits (100.0%), 1976 indexable (100.0% of hits, 100.0% overall), 1976 crystals, 120.4 images/sec.
# 2645 images processed, 2645 hits (100.0%), 2645 indexable (100.0% of hits, 100.0% overall), 2645 crystals, 133.6 images/sec.
# 3303 images processed, 3303 hits (100.0%), 3303 indexable (100.0% of hits, 100.0% overall), 3303 crystals, 131.5 images/sec.
# 3937 images processed, 3937 hits (100.0%), 3937 indexable (100.0% of hits, 100.0% overall), 3937 crystals, 126.6 images/sec.
# Waiting for the last patterns to be processed...
# Worker 3 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4178 4179
# Task ID was: read_queue
# Worker 5 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4179 4180
# Task ID was: read_queue
# Worker 0 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4181 4182
# Task ID was: read_queue
# Worker 7 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4180 4181
# Task ID was: read_queue
# Worker 1 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4182 4183
# Task ID was: read_queue
# Worker 2 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4183 4184
# Task ID was: read_queue
# Worker 4 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4184 4185
# Task ID was: read_queue
# Worker 6 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/LTA/simulation-29/sim.h5 //4185 4186
# Task ID was: read_queue
# Final: 4186 images processed, 4186 hits (100.0%), 4186 indexable (100.0% of hits, 100.0% overall), 4186 crystals.
# Processing XY pairs: 100%|██████████| 1/1 [00:32<00:00, 32.43s/it]
# Error during indexamajig execution: Command 'indexamajig -g /Users/xiaodong/Desktop/simulations/LTA/LTAsim.geom -i /Users/xiaodong/Desktop/simulations/LTA/simulation-29/list.lst -o /Users/xiaodong/Desktop/simulations/LTA/simulation-29/LTAsim_from_file_-512.5_-512.5.stream -p /Users/xiaodong/Desktop/simulations/LTA/LTA.cell -j 8 --no-revalidate --no-half-pixel-shift --peaks=peakfinder9 --min-snr=1 --min-snr-biggest-pix=1 --min-sig=3 --local-bg-radius=3 --indexing=file --fromfile-input-file=/Users/xiaodong/Desktop/simulations/LTA/simulation-29/orientation_matrices.sol --no-check-cell --no-check-peaks --no-retry --no-refine --integration=rings --int-radius=4,5,9 --no-non-hits-in-stream --fix-profile-radius=70000000' died with <Signals.SIGABRT: 6>.
