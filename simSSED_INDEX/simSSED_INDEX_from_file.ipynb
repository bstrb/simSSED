# %% [markdown]
# Indexing using xGandalf (layers = layers of step size )

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/Users/xiaodong/Desktop/simulations/UOX/UOXsim.geom"
cellfile_path = "/Users/xiaodong/Desktop/simulations/UOX/UOX.cell"
input_path =   "/Users/xiaodong/Desktop/simulations/UOX/simulation-30"
output_file_base = "UOXsimUB"

num_threads = 8
x, y = 512.5, 512.5
step_size = 0.5
layers = 0
input_sol_file = "/Users/xiaodong/Desktop/simulations/UOX/simulation-30/UB_matrices.sol"

extra_flags=[
# BASIC OPTIONS
# PEAKFINDING
"--no-revalidate",
"--no-half-pixel-shift",
"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-biggest-pix=1",
"--min-sig=3",
"--local-bg-radius=3",
# INDEXING
"--indexing=file",
f"--fromfile-input-file={input_sol_file}",
"--no-check-cell",
"--no-check-peaks",
"--no-retry",
"--no-refine",

# "--indexing=xgandalf",
# "--no-refine",
# "--xgandalf-sampling-pitch=5"
# "--xgandalf-grad-desc-iterations=1"
# "--xgandalf-tolerance=0.02"

# INTEGRATION
"--integration=rings",
"--int-radius=4,5,10",
# OUTPUT
"--no-non-hits-in-stream",
]

"""Examples of extra flags(see crystfel documentation https://www.desy.de/~twhite/crystfel/manual-indexamajig.html):"""

""" Basic options
"--highres=n",
"--no-image-data",
"""

""" Peakfinding
"--peaks=cxi",
"--peak-radius=inner,middle,outer",
"--min-peaks=n",
"--median-filter=n",
"--filter-noise",
"--no-revalidate",
"--no-half-pixel-shift",

"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",
"""

""" Indexing
"--indexing=xgandalf",

"--tolerance=tol"
"--no-check-cell",
"--no-check-peaks",
"--multi",
"--no-retry",
"--no-refine",

"--xgandalf-sampling-pitch=n"
"--xgandalf-grad-desc-iterations=n"
"--xgandalf-tolerance=n"
"--xgandalf-no-deviation-from-provided-cell"
"--xgandalf-max-lattice-vector-length=n"
"--xgandalf-min-lattice-vector-length=n"
"--xgandalf-max-peaks=n"
"--xgandalf-fast-execution"
"""

""" Integration
"--integration=rings",
"--int-radius=4,5,10",
"--push-res=n",
"--overpredict",
"--cell-parameters-only",
"""

""" Output
"--no-non-hits-in-stream",
"--no-peaks-in-stream",
"--no-refls-in-stream",
"--serial-offset
"""

gandalf_iterator(x, y, geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /Users/xiaodong/Desktop/simulations/UOX/simulation-30/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512.5, y=-512.5
# This is what I understood your unit cell to be:
# orthorhombic I, right handed.
# a      b      c            alpha   beta  gamma
#  80.58  94.49 103.89 A     90.00  90.00  90.00 deg
# Read 100 crystals from /Users/xiaodong/Desktop/simulations/UOX/simulation-30/UB_matrices.sol
# List of indexing methods:
#    0: file-nolatt-nocell        (file - no prior information)
# Indexing parameters:
#                   Check unit cell parameters: off
#                         Check peak alignment: off
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: off
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# 45 images processed, 45 hits (100.0%), 45 indexable (100.0% of hits, 100.0% overall), 45 crystals, 8.9 images/sec.
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# 87 images processed, 87 hits (100.0%), 87 indexable (100.0% of hits, 100.0% overall), 87 crystals, 8.2 images/sec.
# WARNING: Radius determination failed
# Waiting for the last patterns to be processed...
# Worker 1 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //94 95
# Task ID was: read_queue
# Worker 3 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //93 94
# Task ID was: read_queue
# Worker 5 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //97 98
# Task ID was: read_queue
# Worker 0 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //92 93
# Task ID was: read_queue
# Worker 2 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //96 97
# Task ID was: read_queue
# Worker 4 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //95 96
# Task ID was: read_queue
# Worker 7 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //99 100
# Task ID was: read_queue
# Worker 6 was killed by signal 6
# Event ID was: /Users/xiaodong/Desktop/simulations/UOX/simulation-30/sim.h5 //98 99
# Task ID was: read_queue
# Final: 100 images processed, 100 hits (100.0%), 100 indexable (100.0% of hits, 100.0% overall), 100 crystals.
# Processing XY pairs: 100%|██████████| 1/1 [00:11<00:00, 11.80s/it]
# Error during indexamajig execution: Command 'indexamajig -g /var/folders/48/_kfx4z6j10304hbp_lqmpxgm0000gn/T/tmpqwqve_u4.geom -i /Users/xiaodong/Desktop/simulations/UOX/simulation-30/list.lst -o /Users/xiaodong/Desktop/simulations/UOX/simulation-30/UOXsimUB_-512.5_-512.5.stream -p /Users/xiaodong/Desktop/simulations/UOX/UOX.cell -j 8 --no-revalidate --no-half-pixel-shift --peaks=peakfinder9 --min-snr=1 --min-snr-biggest-pix=1 --min-sig=3 --local-bg-radius=3 --indexing=file --fromfile-input-file=/Users/xiaodong/Desktop/simulations/UOX/simulation-30/UB_matrices.sol --no-check-cell --no-check-peaks --no-retry --no-refine --integration=rings --int-radius=4,5,10 --no-non-hits-in-stream' died with <Signals.SIGABRT: 6>.
