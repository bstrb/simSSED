# %% [markdown]
# Indexing using xGandalf (layers = layers of step size )

# %%
from gandalf_iterator import gandalf_iterator

geomfile_path = "/Users/xiaodong/Desktop/UOX-data/UOX1/UOX.geom"
cellfile_path = "/Users/xiaodong/Desktop/UOX-data/UOX1/UOX.cell"
input_path =   "/Users/xiaodong/Desktop/UOX-data/UOX1"
output_file_base = "UOX1"

num_threads = 8
step_size = 0.01
layers = 0
extra_flags=[
    "--int-radius=4,5,9",
    "--tolerance=5,5,5,5",
    # "--push-res=5",
    "--xgandalf-sampling-pitch=5",
    "--xgandalf-grad-desc-iterations=1",
    "--xgandalf-tolerance=0.02",
    "--min-peaks=15",
    # "--overpredict",

    "--peaks=peakfinder8",
    "--threshold=45",
    "--min-snr=3",
    "--min-pix-count=3",
    "--max-pix-count=500",
    "--local-bg-radius=9",
    "--min-res=30",
    "--max-res=500",
]

"""
Examples of extra flags(see crystfel documentation for more):
"--int-radius=4,5,10",
"--min-peaks=n",
"--no-retry",
"--push-res=n",
"--no-check-cell",
"--no-check-peaks",
"--peaks=cxi",
"--no-image-data",
"--xgandalf-max-peaks=150"
"--overpredict",


"--peaks=peakfinder8",
"--threshold=45",
"--min-snr=3",
"--min-pix-count=3",
"--max-pix-count=500",
"--local-bg-radius=9",
"--min-res=30",
"--max-res=500",


"--peaks=peakfinder9",
"--min-snr=1",
"--min-snr-peak-pix=6",
"--min-snr-biggest-pix=1",
"--min-sig=9",
"--min-peak-over-neighbour=5",
"--local-bg-radius=5",

"""

gandalf_iterator(geomfile_path, cellfile_path, input_path, output_file_base, num_threads, step_size, layers, extra_flags=extra_flags)
# Out:
# 'list.lst' has been created with 1 entries at /Users/xiaodong/Desktop/UOX-data/UOX1/list.lst
# Processing XY pairs:   0%|          | 0/1 [00:00<?, ?it/s]
# Running for x=-512, y=-512
# This is what I understood your unit cell to be:
# orthorhombic I, right handed.
# a      b      c            alpha   beta  gamma
#  80.58  94.49 103.89 A     90.00  90.00  90.00 deg
# List of indexing methods:
#    0: xgandalf-nolatt-cell      (xgandalf using cell parameters as prior information)
# Indexing parameters:
#                   Check unit cell parameters: on
#                         Check peak alignment: on
#                    Refine indexing solutions: off
#  Multi-lattice indexing ("delete and retry"): off
#                               Retry indexing: on
# 14 images processed, 14 hits (100.0%), 2 indexable (14.3% of hits, 14.3% overall), 2 crystals, 2.8 images/sec.
# 22 images processed, 22 hits (100.0%), 5 indexable (22.7% of hits, 22.7% overall), 5 crystals, 1.6 images/sec.
# 31 images processed, 31 hits (100.0%), 6 indexable (19.4% of hits, 19.4% overall), 6 crystals, 1.7 images/sec.
# 44 images processed, 44 hits (100.0%), 12 indexable (27.3% of hits, 27.3% overall), 12 crystals, 2.5 images/sec.
# 53 images processed, 53 hits (100.0%), 17 indexable (32.1% of hits, 32.1% overall), 17 crystals, 1.7 images/sec.
# 69 images processed, 67 hits (97.1%), 24 indexable (35.8% of hits, 34.8% overall), 24 crystals, 3.1 images/sec.
# 79 images processed, 77 hits (97.5%), 29 indexable (37.7% of hits, 36.7% overall), 29 crystals, 1.8 images/sec.
# 90 images processed, 88 hits (97.8%), 30 indexable (34.1% of hits, 33.3% overall), 30 crystals, 2.0 images/sec.
# 99 images processed, 97 hits (98.0%), 31 indexable (32.0% of hits, 31.3% overall), 31 crystals, 1.7 images/sec.
# 116 images processed, 114 hits (98.3%), 40 indexable (35.1% of hits, 34.5% overall), 40 crystals, 3.3 images/sec.
# 126 images processed, 124 hits (98.4%), 46 indexable (37.1% of hits, 36.5% overall), 46 crystals, 1.9 images/sec.
# 140 images processed, 138 hits (98.6%), 53 indexable (38.4% of hits, 37.9% overall), 53 crystals, 2.7 images/sec.
# 154 images processed, 152 hits (98.7%), 59 indexable (38.8% of hits, 38.3% overall), 59 crystals, 2.6 images/sec.
# 171 images processed, 168 hits (98.2%), 67 indexable (39.9% of hits, 39.2% overall), 67 crystals, 3.4 images/sec.
# 186 images processed, 183 hits (98.4%), 74 indexable (40.4% of hits, 39.8% overall), 74 crystals, 2.9 images/sec.
# 201 images processed, 198 hits (98.5%), 84 indexable (42.4% of hits, 41.8% overall), 84 crystals, 3.0 images/sec.
# 211 images processed, 208 hits (98.6%), 86 indexable (41.3% of hits, 40.8% overall), 86 crystals, 1.8 images/sec.
# 221 images processed, 218 hits (98.6%), 88 indexable (40.4% of hits, 39.8% overall), 88 crystals, 2.0 images/sec.
# 240 images processed, 237 hits (98.8%), 98 indexable (41.4% of hits, 40.8% overall), 98 crystals, 3.5 images/sec.
# 252 images processed, 249 hits (98.8%), 101 indexable (40.6% of hits, 40.1% overall), 101 crystals, 2.3 images/sec.
# 256 images processed, 253 hits (98.8%), 103 indexable (40.7% of hits, 40.2% overall), 103 crystals, 0.8 images/sec.
# 270 images processed, 267 hits (98.9%), 105 indexable (39.3% of hits, 38.9% overall), 105 crystals, 2.6 images/sec.
# 278 images processed, 275 hits (98.9%), 106 indexable (38.5% of hits, 38.1% overall), 106 crystals, 1.6 images/sec.
# 290 images processed, 287 hits (99.0%), 112 indexable (39.0% of hits, 38.6% overall), 112 crystals, 2.4 images/sec.
# 308 images processed, 305 hits (99.0%), 116 indexable (38.0% of hits, 37.7% overall), 116 crystals, 3.4 images/sec.
# 320 images processed, 317 hits (99.1%), 124 indexable (39.1% of hits, 38.8% overall), 124 crystals, 2.2 images/sec.
# 331 images processed, 328 hits (99.1%), 127 indexable (38.7% of hits, 38.4% overall), 127 crystals, 2.1 images/sec.
# 347 images processed, 344 hits (99.1%), 131 indexable (38.1% of hits, 37.8% overall), 131 crystals, 3.0 images/sec.
# 355 images processed, 352 hits (99.2%), 135 indexable (38.4% of hits, 38.0% overall), 135 crystals, 1.5 images/sec.
# 367 images processed, 364 hits (99.2%), 140 indexable (38.5% of hits, 38.1% overall), 140 crystals, 2.2 images/sec.
# 378 images processed, 375 hits (99.2%), 144 indexable (38.4% of hits, 38.1% overall), 144 crystals, 2.1 images/sec.
# 389 images processed, 386 hits (99.2%), 148 indexable (38.3% of hits, 38.0% overall), 148 crystals, 2.2 images/sec.
# 401 images processed, 398 hits (99.3%), 151 indexable (37.9% of hits, 37.7% overall), 151 crystals, 2.4 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //409
# 414 images processed, 410 hits (99.0%), 157 indexable (38.3% of hits, 37.9% overall), 157 crystals, 2.5 images/sec.
# 429 images processed, 425 hits (99.1%), 162 indexable (38.1% of hits, 37.8% overall), 162 crystals, 2.9 images/sec.
# 438 images processed, 434 hits (99.1%), 165 indexable (38.0% of hits, 37.7% overall), 165 crystals, 1.7 images/sec.
# 449 images processed, 445 hits (99.1%), 166 indexable (37.3% of hits, 37.0% overall), 166 crystals, 2.1 images/sec.
# 462 images processed, 458 hits (99.1%), 168 indexable (36.7% of hits, 36.4% overall), 168 crystals, 2.6 images/sec.
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //476
# 478 images processed, 474 hits (99.2%), 176 indexable (37.1% of hits, 36.8% overall), 176 crystals, 3.0 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //482
# 488 images processed, 484 hits (99.2%), 181 indexable (37.4% of hits, 37.1% overall), 181 crystals, 2.0 images/sec.
# 501 images processed, 497 hits (99.2%), 189 indexable (38.0% of hits, 37.7% overall), 189 crystals, 2.6 images/sec.
# 513 images processed, 509 hits (99.2%), 192 indexable (37.7% of hits, 37.4% overall), 192 crystals, 2.4 images/sec.
# 526 images processed, 522 hits (99.2%), 197 indexable (37.7% of hits, 37.5% overall), 197 crystals, 2.5 images/sec.
# 540 images processed, 536 hits (99.3%), 203 indexable (37.9% of hits, 37.6% overall), 203 crystals, 2.8 images/sec.
# 552 images processed, 548 hits (99.3%), 207 indexable (37.8% of hits, 37.5% overall), 207 crystals, 2.4 images/sec.
# 564 images processed, 560 hits (99.3%), 214 indexable (38.2% of hits, 37.9% overall), 214 crystals, 2.4 images/sec.
# 577 images processed, 573 hits (99.3%), 218 indexable (38.0% of hits, 37.8% overall), 218 crystals, 2.5 images/sec.
# 589 images processed, 585 hits (99.3%), 224 indexable (38.3% of hits, 38.0% overall), 224 crystals, 2.3 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //596
# 601 images processed, 596 hits (99.2%), 228 indexable (38.3% of hits, 37.9% overall), 228 crystals, 2.3 images/sec.
# 612 images processed, 607 hits (99.2%), 233 indexable (38.4% of hits, 38.1% overall), 233 crystals, 2.1 images/sec.
# 621 images processed, 616 hits (99.2%), 238 indexable (38.6% of hits, 38.3% overall), 238 crystals, 1.7 images/sec.
# 638 images processed, 633 hits (99.2%), 245 indexable (38.7% of hits, 38.4% overall), 245 crystals, 3.3 images/sec.
# 649 images processed, 644 hits (99.2%), 249 indexable (38.7% of hits, 38.4% overall), 249 crystals, 2.1 images/sec.
# 660 images processed, 655 hits (99.2%), 252 indexable (38.5% of hits, 38.2% overall), 252 crystals, 2.1 images/sec.
# 673 images processed, 668 hits (99.3%), 256 indexable (38.3% of hits, 38.0% overall), 256 crystals, 2.4 images/sec.
# 685 images processed, 680 hits (99.3%), 260 indexable (38.2% of hits, 38.0% overall), 260 crystals, 2.4 images/sec.
# 694 images processed, 689 hits (99.3%), 263 indexable (38.2% of hits, 37.9% overall), 263 crystals, 1.8 images/sec.
# 707 images processed, 702 hits (99.3%), 271 indexable (38.6% of hits, 38.3% overall), 271 crystals, 2.6 images/sec.
# 720 images processed, 715 hits (99.3%), 277 indexable (38.7% of hits, 38.5% overall), 277 crystals, 2.4 images/sec.
# 735 images processed, 730 hits (99.3%), 285 indexable (39.0% of hits, 38.8% overall), 285 crystals, 2.9 images/sec.
# 749 images processed, 744 hits (99.3%), 293 indexable (39.4% of hits, 39.1% overall), 293 crystals, 2.7 images/sec.
# 760 images processed, 755 hits (99.3%), 296 indexable (39.2% of hits, 38.9% overall), 296 crystals, 2.0 images/sec.
# 777 images processed, 772 hits (99.4%), 300 indexable (38.9% of hits, 38.6% overall), 300 crystals, 3.4 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //780
# 796 images processed, 791 hits (99.4%), 314 indexable (39.7% of hits, 39.4% overall), 314 crystals, 3.6 images/sec.
# WARNING: 2 implausibly negative reflections in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //783
# 809 images processed, 804 hits (99.4%), 322 indexable (40.0% of hits, 39.8% overall), 322 crystals, 2.4 images/sec.
# WARNING: Radius determination failed
# 825 images processed, 820 hits (99.4%), 330 indexable (40.2% of hits, 40.0% overall), 330 crystals, 3.2 images/sec.
# 844 images processed, 839 hits (99.4%), 336 indexable (40.0% of hits, 39.8% overall), 336 crystals, 3.6 images/sec.
# 855 images processed, 850 hits (99.4%), 341 indexable (40.1% of hits, 39.9% overall), 341 crystals, 2.1 images/sec.
# 870 images processed, 865 hits (99.4%), 346 indexable (40.0% of hits, 39.8% overall), 346 crystals, 2.9 images/sec.
# 884 images processed, 878 hits (99.3%), 350 indexable (39.9% of hits, 39.6% overall), 350 crystals, 2.8 images/sec.
# 893 images processed, 887 hits (99.3%), 354 indexable (39.9% of hits, 39.6% overall), 354 crystals, 1.7 images/sec.
# 905 images processed, 899 hits (99.3%), 358 indexable (39.8% of hits, 39.6% overall), 358 crystals, 2.3 images/sec.
# 915 images processed, 909 hits (99.3%), 364 indexable (40.0% of hits, 39.8% overall), 364 crystals, 1.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //921
# 924 images processed, 918 hits (99.4%), 367 indexable (40.0% of hits, 39.7% overall), 367 crystals, 1.8 images/sec.
# 937 images processed, 931 hits (99.4%), 375 indexable (40.3% of hits, 40.0% overall), 375 crystals, 2.5 images/sec.
# WARNING: Radius determination failed
# 952 images processed, 946 hits (99.4%), 386 indexable (40.8% of hits, 40.5% overall), 386 crystals, 2.8 images/sec.
# 966 images processed, 959 hits (99.3%), 393 indexable (41.0% of hits, 40.7% overall), 393 crystals, 2.7 images/sec.
# 976 images processed, 969 hits (99.3%), 397 indexable (41.0% of hits, 40.7% overall), 397 crystals, 1.9 images/sec.
# 991 images processed, 984 hits (99.3%), 403 indexable (41.0% of hits, 40.7% overall), 403 crystals, 2.8 images/sec.
# 1005 images processed, 998 hits (99.3%), 409 indexable (41.0% of hits, 40.7% overall), 409 crystals, 2.7 images/sec.
# WARNING: Radius determination failed
# 1019 images processed, 1012 hits (99.3%), 414 indexable (40.9% of hits, 40.6% overall), 414 crystals, 2.8 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1032
# 1031 images processed, 1024 hits (99.3%), 423 indexable (41.3% of hits, 41.0% overall), 423 crystals, 2.3 images/sec.
# 1043 images processed, 1036 hits (99.3%), 431 indexable (41.6% of hits, 41.3% overall), 431 crystals, 2.4 images/sec.
# 1057 images processed, 1050 hits (99.3%), 437 indexable (41.6% of hits, 41.3% overall), 437 crystals, 2.7 images/sec.
# 1073 images processed, 1066 hits (99.3%), 443 indexable (41.6% of hits, 41.3% overall), 443 crystals, 2.9 images/sec.
# 1087 images processed, 1080 hits (99.4%), 450 indexable (41.7% of hits, 41.4% overall), 450 crystals, 2.7 images/sec.
# 1104 images processed, 1097 hits (99.4%), 455 indexable (41.5% of hits, 41.2% overall), 455 crystals, 3.3 images/sec.
# 1119 images processed, 1112 hits (99.4%), 459 indexable (41.3% of hits, 41.0% overall), 459 crystals, 2.8 images/sec.
# 1129 images processed, 1122 hits (99.4%), 466 indexable (41.5% of hits, 41.3% overall), 466 crystals, 2.0 images/sec.
# 1140 images processed, 1133 hits (99.4%), 472 indexable (41.7% of hits, 41.4% overall), 472 crystals, 2.1 images/sec.
# 1145 images processed, 1138 hits (99.4%), 473 indexable (41.6% of hits, 41.3% overall), 473 crystals, 1.0 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1151
# 1156 images processed, 1149 hits (99.4%), 478 indexable (41.6% of hits, 41.3% overall), 478 crystals, 2.1 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1155
# 1166 images processed, 1159 hits (99.4%), 484 indexable (41.8% of hits, 41.5% overall), 484 crystals, 2.0 images/sec.
# 1178 images processed, 1171 hits (99.4%), 487 indexable (41.6% of hits, 41.3% overall), 487 crystals, 2.3 images/sec.
# 1187 images processed, 1180 hits (99.4%), 491 indexable (41.6% of hits, 41.4% overall), 491 crystals, 1.7 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1183
# 1202 images processed, 1195 hits (99.4%), 498 indexable (41.7% of hits, 41.4% overall), 498 crystals, 2.9 images/sec.
# 1218 images processed, 1210 hits (99.3%), 507 indexable (41.9% of hits, 41.6% overall), 507 crystals, 3.0 images/sec.
# 1224 images processed, 1216 hits (99.3%), 509 indexable (41.9% of hits, 41.6% overall), 509 crystals, 1.2 images/sec.
# 1235 images processed, 1227 hits (99.4%), 514 indexable (41.9% of hits, 41.6% overall), 514 crystals, 2.0 images/sec.
# 1245 images processed, 1237 hits (99.4%), 515 indexable (41.6% of hits, 41.4% overall), 515 crystals, 1.8 images/sec.
# 1258 images processed, 1250 hits (99.4%), 526 indexable (42.1% of hits, 41.8% overall), 526 crystals, 2.5 images/sec.
# 1272 images processed, 1264 hits (99.4%), 529 indexable (41.9% of hits, 41.6% overall), 529 crystals, 2.6 images/sec.
# 1285 images processed, 1277 hits (99.4%), 535 indexable (41.9% of hits, 41.6% overall), 535 crystals, 2.6 images/sec.
# 1301 images processed, 1293 hits (99.4%), 544 indexable (42.1% of hits, 41.8% overall), 544 crystals, 3.1 images/sec.
# 1311 images processed, 1303 hits (99.4%), 550 indexable (42.2% of hits, 42.0% overall), 550 crystals, 2.0 images/sec.
# 1325 images processed, 1317 hits (99.4%), 557 indexable (42.3% of hits, 42.0% overall), 557 crystals, 2.7 images/sec.
# 1334 images processed, 1326 hits (99.4%), 559 indexable (42.2% of hits, 41.9% overall), 559 crystals, 1.7 images/sec.
# 1345 images processed, 1337 hits (99.4%), 564 indexable (42.2% of hits, 41.9% overall), 564 crystals, 2.1 images/sec.
# 1357 images processed, 1349 hits (99.4%), 568 indexable (42.1% of hits, 41.9% overall), 568 crystals, 2.3 images/sec.
# 1373 images processed, 1365 hits (99.4%), 572 indexable (41.9% of hits, 41.7% overall), 572 crystals, 3.1 images/sec.
# 1381 images processed, 1373 hits (99.4%), 575 indexable (41.9% of hits, 41.6% overall), 575 crystals, 1.5 images/sec.
# 1396 images processed, 1388 hits (99.4%), 587 indexable (42.3% of hits, 42.0% overall), 587 crystals, 2.9 images/sec.
# 1408 images processed, 1400 hits (99.4%), 591 indexable (42.2% of hits, 42.0% overall), 591 crystals, 2.4 images/sec.
# 1418 images processed, 1410 hits (99.4%), 598 indexable (42.4% of hits, 42.2% overall), 598 crystals, 2.0 images/sec.
# 1430 images processed, 1422 hits (99.4%), 604 indexable (42.5% of hits, 42.2% overall), 604 crystals, 2.3 images/sec.
# 1442 images processed, 1434 hits (99.4%), 610 indexable (42.5% of hits, 42.3% overall), 610 crystals, 2.4 images/sec.
# 1457 images processed, 1449 hits (99.5%), 617 indexable (42.6% of hits, 42.3% overall), 617 crystals, 2.9 images/sec.
# 1470 images processed, 1462 hits (99.5%), 618 indexable (42.3% of hits, 42.0% overall), 618 crystals, 2.4 images/sec.
# 1481 images processed, 1473 hits (99.5%), 626 indexable (42.5% of hits, 42.3% overall), 626 crystals, 2.1 images/sec.
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1489
# 1488 images processed, 1480 hits (99.5%), 629 indexable (42.5% of hits, 42.3% overall), 629 crystals, 1.4 images/sec.
# 1500 images processed, 1492 hits (99.5%), 634 indexable (42.5% of hits, 42.3% overall), 634 crystals, 2.3 images/sec.
# 1511 images processed, 1503 hits (99.5%), 638 indexable (42.4% of hits, 42.2% overall), 638 crystals, 2.2 images/sec.
# 1522 images processed, 1514 hits (99.5%), 642 indexable (42.4% of hits, 42.2% overall), 642 crystals, 2.1 images/sec.
# 1530 images processed, 1522 hits (99.5%), 643 indexable (42.2% of hits, 42.0% overall), 643 crystals, 1.6 images/sec.
# 1544 images processed, 1536 hits (99.5%), 651 indexable (42.4% of hits, 42.2% overall), 651 crystals, 2.7 images/sec.
# 1556 images processed, 1548 hits (99.5%), 660 indexable (42.6% of hits, 42.4% overall), 660 crystals, 2.3 images/sec.
# WARNING: Radius determination failed
# 1569 images processed, 1561 hits (99.5%), 666 indexable (42.7% of hits, 42.4% overall), 666 crystals, 2.4 images/sec.
# 1583 images processed, 1574 hits (99.4%), 674 indexable (42.8% of hits, 42.6% overall), 674 crystals, 2.6 images/sec.
# 1596 images processed, 1587 hits (99.4%), 681 indexable (42.9% of hits, 42.7% overall), 681 crystals, 2.5 images/sec.
# 1608 images processed, 1599 hits (99.4%), 686 indexable (42.9% of hits, 42.7% overall), 686 crystals, 2.2 images/sec.
# 1624 images processed, 1615 hits (99.4%), 696 indexable (43.1% of hits, 42.9% overall), 696 crystals, 3.2 images/sec.
# 1634 images processed, 1625 hits (99.4%), 698 indexable (43.0% of hits, 42.7% overall), 698 crystals, 2.0 images/sec.
# 1646 images processed, 1637 hits (99.5%), 702 indexable (42.9% of hits, 42.6% overall), 702 crystals, 2.4 images/sec.
# 1654 images processed, 1645 hits (99.5%), 705 indexable (42.9% of hits, 42.6% overall), 705 crystals, 1.5 images/sec.
# 1671 images processed, 1662 hits (99.5%), 708 indexable (42.6% of hits, 42.4% overall), 708 crystals, 3.1 images/sec.
# 1680 images processed, 1671 hits (99.5%), 712 indexable (42.6% of hits, 42.4% overall), 712 crystals, 1.8 images/sec.
# 1690 images processed, 1681 hits (99.5%), 715 indexable (42.5% of hits, 42.3% overall), 715 crystals, 1.9 images/sec.
# 1705 images processed, 1696 hits (99.5%), 720 indexable (42.5% of hits, 42.2% overall), 720 crystals, 2.9 images/sec.
# 1718 images processed, 1709 hits (99.5%), 727 indexable (42.5% of hits, 42.3% overall), 727 crystals, 2.6 images/sec.
# 1732 images processed, 1723 hits (99.5%), 730 indexable (42.4% of hits, 42.1% overall), 730 crystals, 2.8 images/sec.
# 1744 images processed, 1734 hits (99.4%), 735 indexable (42.4% of hits, 42.1% overall), 735 crystals, 2.3 images/sec.
# 1761 images processed, 1751 hits (99.4%), 744 indexable (42.5% of hits, 42.2% overall), 744 crystals, 3.3 images/sec.
# 1769 images processed, 1759 hits (99.4%), 751 indexable (42.7% of hits, 42.5% overall), 751 crystals, 1.5 images/sec.
# 1781 images processed, 1771 hits (99.4%), 754 indexable (42.6% of hits, 42.3% overall), 754 crystals, 2.4 images/sec.
# 1791 images processed, 1781 hits (99.4%), 760 indexable (42.7% of hits, 42.4% overall), 760 crystals, 1.8 images/sec.
# 1801 images processed, 1791 hits (99.4%), 766 indexable (42.8% of hits, 42.5% overall), 766 crystals, 1.9 images/sec.
# 1814 images processed, 1804 hits (99.4%), 771 indexable (42.7% of hits, 42.5% overall), 771 crystals, 2.5 images/sec.
# WARNING: Radius determination failed
# 1830 images processed, 1819 hits (99.4%), 779 indexable (42.8% of hits, 42.6% overall), 779 crystals, 2.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1833
# 1848 images processed, 1837 hits (99.4%), 789 indexable (43.0% of hits, 42.7% overall), 789 crystals, 3.6 images/sec.
# 1857 images processed, 1846 hits (99.4%), 790 indexable (42.8% of hits, 42.5% overall), 790 crystals, 1.8 images/sec.
# 1874 images processed, 1863 hits (99.4%), 802 indexable (43.0% of hits, 42.8% overall), 802 crystals, 3.2 images/sec.
# 1889 images processed, 1878 hits (99.4%), 809 indexable (43.1% of hits, 42.8% overall), 809 crystals, 2.9 images/sec.
# 1904 images processed, 1893 hits (99.4%), 817 indexable (43.2% of hits, 42.9% overall), 817 crystals, 2.9 images/sec.
# 1918 images processed, 1907 hits (99.4%), 820 indexable (43.0% of hits, 42.8% overall), 820 crystals, 2.6 images/sec.
# 1929 images processed, 1918 hits (99.4%), 826 indexable (43.1% of hits, 42.8% overall), 826 crystals, 2.2 images/sec.
# 1943 images processed, 1931 hits (99.4%), 832 indexable (43.1% of hits, 42.8% overall), 832 crystals, 2.6 images/sec.
# 1955 images processed, 1943 hits (99.4%), 838 indexable (43.1% of hits, 42.9% overall), 838 crystals, 2.3 images/sec.
# 1967 images processed, 1955 hits (99.4%), 842 indexable (43.1% of hits, 42.8% overall), 842 crystals, 2.4 images/sec.
# 1977 images processed, 1965 hits (99.4%), 843 indexable (42.9% of hits, 42.6% overall), 843 crystals, 1.8 images/sec.
# 1987 images processed, 1975 hits (99.4%), 845 indexable (42.8% of hits, 42.5% overall), 845 crystals, 1.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //1991
# WARNING: Radius determination failed
# 1998 images processed, 1985 hits (99.3%), 850 indexable (42.8% of hits, 42.5% overall), 850 crystals, 2.0 images/sec.
# 2005 images processed, 1992 hits (99.4%), 852 indexable (42.8% of hits, 42.5% overall), 852 crystals, 1.3 images/sec.
# 2018 images processed, 2005 hits (99.4%), 855 indexable (42.6% of hits, 42.4% overall), 855 crystals, 2.6 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2034
# 2038 images processed, 2025 hits (99.4%), 866 indexable (42.8% of hits, 42.5% overall), 866 crystals, 3.8 images/sec.
# 2050 images processed, 2037 hits (99.4%), 869 indexable (42.7% of hits, 42.4% overall), 869 crystals, 2.2 images/sec.
# WARNING: Radius determination failed
# 2064 images processed, 2051 hits (99.4%), 874 indexable (42.6% of hits, 42.3% overall), 874 crystals, 2.7 images/sec.
# 2073 images processed, 2060 hits (99.4%), 876 indexable (42.5% of hits, 42.3% overall), 876 crystals, 1.7 images/sec.
# 2084 images processed, 2071 hits (99.4%), 879 indexable (42.4% of hits, 42.2% overall), 879 crystals, 2.2 images/sec.
# 2097 images processed, 2084 hits (99.4%), 886 indexable (42.5% of hits, 42.3% overall), 886 crystals, 2.5 images/sec.
# WARNING: Radius determination failed
# 2106 images processed, 2093 hits (99.4%), 890 indexable (42.5% of hits, 42.3% overall), 890 crystals, 1.8 images/sec.
# 2119 images processed, 2106 hits (99.4%), 893 indexable (42.4% of hits, 42.1% overall), 893 crystals, 2.6 images/sec.
# 2131 images processed, 2118 hits (99.4%), 900 indexable (42.5% of hits, 42.2% overall), 900 crystals, 2.3 images/sec.
# 2147 images processed, 2134 hits (99.4%), 908 indexable (42.5% of hits, 42.3% overall), 908 crystals, 3.0 images/sec.
# 2162 images processed, 2149 hits (99.4%), 918 indexable (42.7% of hits, 42.5% overall), 918 crystals, 3.0 images/sec.
# 2173 images processed, 2160 hits (99.4%), 923 indexable (42.7% of hits, 42.5% overall), 923 crystals, 2.1 images/sec.
# 2187 images processed, 2174 hits (99.4%), 929 indexable (42.7% of hits, 42.5% overall), 929 crystals, 2.7 images/sec.
# 2198 images processed, 2185 hits (99.4%), 934 indexable (42.7% of hits, 42.5% overall), 934 crystals, 2.1 images/sec.
# 2213 images processed, 2200 hits (99.4%), 941 indexable (42.8% of hits, 42.5% overall), 941 crystals, 2.8 images/sec.
# 2227 images processed, 2214 hits (99.4%), 947 indexable (42.8% of hits, 42.5% overall), 947 crystals, 2.7 images/sec.
# WARNING: 2 implausibly negative reflections in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2243
# 2243 images processed, 2230 hits (99.4%), 958 indexable (43.0% of hits, 42.7% overall), 958 crystals, 3.1 images/sec.
# 2257 images processed, 2244 hits (99.4%), 963 indexable (42.9% of hits, 42.7% overall), 963 crystals, 2.8 images/sec.
# 2271 images processed, 2258 hits (99.4%), 969 indexable (42.9% of hits, 42.7% overall), 969 crystals, 2.6 images/sec.
# 2281 images processed, 2268 hits (99.4%), 973 indexable (42.9% of hits, 42.7% overall), 973 crystals, 1.9 images/sec.
# WARNING: Radius determination failed
# 2297 images processed, 2284 hits (99.4%), 981 indexable (43.0% of hits, 42.7% overall), 981 crystals, 2.9 images/sec.
# 2310 images processed, 2297 hits (99.4%), 987 indexable (43.0% of hits, 42.7% overall), 987 crystals, 2.6 images/sec.
# 2321 images processed, 2308 hits (99.4%), 993 indexable (43.0% of hits, 42.8% overall), 993 crystals, 2.2 images/sec.
# 2332 images processed, 2319 hits (99.4%), 997 indexable (43.0% of hits, 42.8% overall), 997 crystals, 2.2 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2333
# 2344 images processed, 2331 hits (99.4%), 998 indexable (42.8% of hits, 42.6% overall), 998 crystals, 2.3 images/sec.
# 2355 images processed, 2342 hits (99.4%), 1002 indexable (42.8% of hits, 42.5% overall), 1002 crystals, 2.2 images/sec.
# 2366 images processed, 2352 hits (99.4%), 1005 indexable (42.7% of hits, 42.5% overall), 1005 crystals, 2.1 images/sec.
# 2381 images processed, 2367 hits (99.4%), 1010 indexable (42.7% of hits, 42.4% overall), 1010 crystals, 2.9 images/sec.
# 2391 images processed, 2376 hits (99.4%), 1013 indexable (42.6% of hits, 42.4% overall), 1013 crystals, 1.9 images/sec.
# 2399 images processed, 2384 hits (99.4%), 1017 indexable (42.7% of hits, 42.4% overall), 1017 crystals, 1.5 images/sec.
# 2407 images processed, 2392 hits (99.4%), 1018 indexable (42.6% of hits, 42.3% overall), 1018 crystals, 1.5 images/sec.
# 2419 images processed, 2404 hits (99.4%), 1026 indexable (42.7% of hits, 42.4% overall), 1026 crystals, 2.4 images/sec.
# 2435 images processed, 2420 hits (99.4%), 1035 indexable (42.8% of hits, 42.5% overall), 1035 crystals, 3.1 images/sec.
# 2442 images processed, 2427 hits (99.4%), 1038 indexable (42.8% of hits, 42.5% overall), 1038 crystals, 1.3 images/sec.
# 2455 images processed, 2440 hits (99.4%), 1043 indexable (42.7% of hits, 42.5% overall), 1043 crystals, 2.6 images/sec.
# 2467 images processed, 2452 hits (99.4%), 1049 indexable (42.8% of hits, 42.5% overall), 1049 crystals, 2.3 images/sec.
# 2475 images processed, 2460 hits (99.4%), 1054 indexable (42.8% of hits, 42.6% overall), 1054 crystals, 1.6 images/sec.
# 2484 images processed, 2469 hits (99.4%), 1058 indexable (42.9% of hits, 42.6% overall), 1058 crystals, 1.7 images/sec.
# 2492 images processed, 2477 hits (99.4%), 1062 indexable (42.9% of hits, 42.6% overall), 1062 crystals, 1.6 images/sec.
# 2506 images processed, 2491 hits (99.4%), 1071 indexable (43.0% of hits, 42.7% overall), 1071 crystals, 2.7 images/sec.
# WARNING: Radius determination failed
# 2520 images processed, 2505 hits (99.4%), 1076 indexable (43.0% of hits, 42.7% overall), 1076 crystals, 2.8 images/sec.
# 2531 images processed, 2516 hits (99.4%), 1081 indexable (43.0% of hits, 42.7% overall), 1081 crystals, 2.1 images/sec.
# 2543 images processed, 2528 hits (99.4%), 1086 indexable (43.0% of hits, 42.7% overall), 1086 crystals, 2.4 images/sec.
# 2558 images processed, 2543 hits (99.4%), 1089 indexable (42.8% of hits, 42.6% overall), 1089 crystals, 2.9 images/sec.
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2560
# 2570 images processed, 2555 hits (99.4%), 1096 indexable (42.9% of hits, 42.6% overall), 1096 crystals, 2.4 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2576
# 2582 images processed, 2567 hits (99.4%), 1101 indexable (42.9% of hits, 42.6% overall), 1101 crystals, 2.4 images/sec.
# WARNING: Radius determination failed
# 2594 images processed, 2579 hits (99.4%), 1107 indexable (42.9% of hits, 42.7% overall), 1107 crystals, 2.3 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2611
# 2606 images processed, 2591 hits (99.4%), 1113 indexable (43.0% of hits, 42.7% overall), 1113 crystals, 2.3 images/sec.
# 2618 images processed, 2603 hits (99.4%), 1117 indexable (42.9% of hits, 42.7% overall), 1117 crystals, 2.3 images/sec.
# 2633 images processed, 2618 hits (99.4%), 1123 indexable (42.9% of hits, 42.7% overall), 1123 crystals, 2.8 images/sec.
# 2649 images processed, 2634 hits (99.4%), 1126 indexable (42.7% of hits, 42.5% overall), 1126 crystals, 2.9 images/sec.
# WARNING: Radius determination failed
# 2663 images processed, 2648 hits (99.4%), 1134 indexable (42.8% of hits, 42.6% overall), 1134 crystals, 2.7 images/sec.
# 2677 images processed, 2662 hits (99.4%), 1140 indexable (42.8% of hits, 42.6% overall), 1140 crystals, 2.8 images/sec.
# 2687 images processed, 2672 hits (99.4%), 1145 indexable (42.9% of hits, 42.6% overall), 1145 crystals, 1.9 images/sec.
# WARNING: Radius determination failed
# 2704 images processed, 2689 hits (99.4%), 1151 indexable (42.8% of hits, 42.6% overall), 1151 crystals, 3.4 images/sec.
# 2718 images processed, 2703 hits (99.4%), 1156 indexable (42.8% of hits, 42.5% overall), 1156 crystals, 2.7 images/sec.
# 2729 images processed, 2714 hits (99.5%), 1163 indexable (42.9% of hits, 42.6% overall), 1163 crystals, 2.1 images/sec.
# 2738 images processed, 2723 hits (99.5%), 1168 indexable (42.9% of hits, 42.7% overall), 1168 crystals, 1.8 images/sec.
# 2751 images processed, 2736 hits (99.5%), 1176 indexable (43.0% of hits, 42.7% overall), 1176 crystals, 2.5 images/sec.
# 2766 images processed, 2750 hits (99.4%), 1183 indexable (43.0% of hits, 42.8% overall), 1183 crystals, 2.9 images/sec.
# 2773 images processed, 2757 hits (99.4%), 1188 indexable (43.1% of hits, 42.8% overall), 1188 crystals, 1.4 images/sec.
# 2786 images processed, 2770 hits (99.4%), 1196 indexable (43.2% of hits, 42.9% overall), 1196 crystals, 2.4 images/sec.
# 2798 images processed, 2782 hits (99.4%), 1202 indexable (43.2% of hits, 43.0% overall), 1202 crystals, 2.4 images/sec.
# 2810 images processed, 2794 hits (99.4%), 1205 indexable (43.1% of hits, 42.9% overall), 1205 crystals, 2.4 images/sec.
# 2822 images processed, 2806 hits (99.4%), 1211 indexable (43.2% of hits, 42.9% overall), 1211 crystals, 2.3 images/sec.
# 2830 images processed, 2814 hits (99.4%), 1213 indexable (43.1% of hits, 42.9% overall), 1213 crystals, 1.6 images/sec.
# 2842 images processed, 2826 hits (99.4%), 1217 indexable (43.1% of hits, 42.8% overall), 1217 crystals, 2.2 images/sec.
# 2857 images processed, 2841 hits (99.4%), 1225 indexable (43.1% of hits, 42.9% overall), 1225 crystals, 2.9 images/sec.
# 2866 images processed, 2850 hits (99.4%), 1229 indexable (43.1% of hits, 42.9% overall), 1229 crystals, 1.7 images/sec.
# 2879 images processed, 2863 hits (99.4%), 1237 indexable (43.2% of hits, 43.0% overall), 1237 crystals, 2.5 images/sec.
# 2886 images processed, 2870 hits (99.4%), 1240 indexable (43.2% of hits, 43.0% overall), 1240 crystals, 1.4 images/sec.
# 2900 images processed, 2884 hits (99.4%), 1244 indexable (43.1% of hits, 42.9% overall), 1244 crystals, 2.8 images/sec.
# WARNING: Radius determination failed
# 2913 images processed, 2897 hits (99.5%), 1246 indexable (43.0% of hits, 42.8% overall), 1246 crystals, 2.4 images/sec.
# 2924 images processed, 2908 hits (99.5%), 1248 indexable (42.9% of hits, 42.7% overall), 1248 crystals, 2.1 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2923
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //2931
# 2940 images processed, 2924 hits (99.5%), 1255 indexable (42.9% of hits, 42.7% overall), 1255 crystals, 3.1 images/sec.
# 2951 images processed, 2935 hits (99.5%), 1259 indexable (42.9% of hits, 42.7% overall), 1259 crystals, 2.1 images/sec.
# 2965 images processed, 2949 hits (99.5%), 1265 indexable (42.9% of hits, 42.7% overall), 1265 crystals, 2.7 images/sec.
# 2979 images processed, 2963 hits (99.5%), 1267 indexable (42.8% of hits, 42.5% overall), 1267 crystals, 2.7 images/sec.
# 2991 images processed, 2975 hits (99.5%), 1271 indexable (42.7% of hits, 42.5% overall), 1271 crystals, 2.3 images/sec.
# 3006 images processed, 2990 hits (99.5%), 1277 indexable (42.7% of hits, 42.5% overall), 1277 crystals, 2.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3017
# 3021 images processed, 3005 hits (99.5%), 1285 indexable (42.8% of hits, 42.5% overall), 1285 crystals, 2.8 images/sec.
# 3034 images processed, 3018 hits (99.5%), 1294 indexable (42.9% of hits, 42.6% overall), 1294 crystals, 2.5 images/sec.
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3046
# 3045 images processed, 3029 hits (99.5%), 1302 indexable (43.0% of hits, 42.8% overall), 1302 crystals, 2.1 images/sec.
# 3056 images processed, 3040 hits (99.5%), 1307 indexable (43.0% of hits, 42.8% overall), 1307 crystals, 2.1 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3062
# 3072 images processed, 3056 hits (99.5%), 1311 indexable (42.9% of hits, 42.7% overall), 1311 crystals, 2.9 images/sec.
# 3084 images processed, 3068 hits (99.5%), 1315 indexable (42.9% of hits, 42.6% overall), 1315 crystals, 2.4 images/sec.
# 3091 images processed, 3075 hits (99.5%), 1316 indexable (42.8% of hits, 42.6% overall), 1316 crystals, 1.3 images/sec.
# 3105 images processed, 3089 hits (99.5%), 1324 indexable (42.9% of hits, 42.6% overall), 1324 crystals, 2.7 images/sec.
# 3116 images processed, 3100 hits (99.5%), 1330 indexable (42.9% of hits, 42.7% overall), 1330 crystals, 2.1 images/sec.
# 3128 images processed, 3112 hits (99.5%), 1335 indexable (42.9% of hits, 42.7% overall), 1335 crystals, 2.2 images/sec.
# 3137 images processed, 3121 hits (99.5%), 1339 indexable (42.9% of hits, 42.7% overall), 1339 crystals, 1.7 images/sec.
# 3154 images processed, 3135 hits (99.4%), 1345 indexable (42.9% of hits, 42.6% overall), 1345 crystals, 3.2 images/sec.
# 3169 images processed, 3150 hits (99.4%), 1355 indexable (43.0% of hits, 42.8% overall), 1355 crystals, 3.0 images/sec.
# WARNING: Radius determination failed
# 3183 images processed, 3164 hits (99.4%), 1359 indexable (43.0% of hits, 42.7% overall), 1359 crystals, 2.7 images/sec.
# 3196 images processed, 3177 hits (99.4%), 1367 indexable (43.0% of hits, 42.8% overall), 1367 crystals, 2.5 images/sec.
# 3211 images processed, 3192 hits (99.4%), 1375 indexable (43.1% of hits, 42.8% overall), 1375 crystals, 3.0 images/sec.
# 3225 images processed, 3206 hits (99.4%), 1381 indexable (43.1% of hits, 42.8% overall), 1381 crystals, 2.7 images/sec.
# 3240 images processed, 3221 hits (99.4%), 1387 indexable (43.1% of hits, 42.8% overall), 1387 crystals, 2.9 images/sec.
# 3254 images processed, 3235 hits (99.4%), 1396 indexable (43.2% of hits, 42.9% overall), 1396 crystals, 2.7 images/sec.
# 3268 images processed, 3249 hits (99.4%), 1399 indexable (43.1% of hits, 42.8% overall), 1399 crystals, 2.8 images/sec.
# 3281 images processed, 3262 hits (99.4%), 1408 indexable (43.2% of hits, 42.9% overall), 1408 crystals, 2.4 images/sec.
# 3295 images processed, 3276 hits (99.4%), 1416 indexable (43.2% of hits, 43.0% overall), 1416 crystals, 2.7 images/sec.
# 3307 images processed, 3288 hits (99.4%), 1421 indexable (43.2% of hits, 43.0% overall), 1421 crystals, 2.4 images/sec.
# 3323 images processed, 3304 hits (99.4%), 1425 indexable (43.1% of hits, 42.9% overall), 1425 crystals, 3.1 images/sec.
# WARNING: Radius determination failed
# WARNING: Radius determination failed
# 3340 images processed, 3320 hits (99.4%), 1433 indexable (43.2% of hits, 42.9% overall), 1433 crystals, 3.3 images/sec.
# 3356 images processed, 3336 hits (99.4%), 1446 indexable (43.3% of hits, 43.1% overall), 1446 crystals, 3.0 images/sec.
# 3371 images processed, 3351 hits (99.4%), 1450 indexable (43.3% of hits, 43.0% overall), 1450 crystals, 2.9 images/sec.
# 3391 images processed, 3370 hits (99.4%), 1457 indexable (43.2% of hits, 43.0% overall), 1457 crystals, 4.0 images/sec.
# 3400 images processed, 3379 hits (99.4%), 1460 indexable (43.2% of hits, 42.9% overall), 1460 crystals, 1.8 images/sec.
# 3415 images processed, 3394 hits (99.4%), 1466 indexable (43.2% of hits, 42.9% overall), 1466 crystals, 2.9 images/sec.
# 3425 images processed, 3404 hits (99.4%), 1469 indexable (43.2% of hits, 42.9% overall), 1469 crystals, 1.9 images/sec.
# 3434 images processed, 3413 hits (99.4%), 1471 indexable (43.1% of hits, 42.8% overall), 1471 crystals, 1.7 images/sec.
# WARNING: Radius determination failed
# 3446 images processed, 3424 hits (99.4%), 1477 indexable (43.1% of hits, 42.9% overall), 1477 crystals, 2.4 images/sec.
# 3456 images processed, 3434 hits (99.4%), 1481 indexable (43.1% of hits, 42.9% overall), 1481 crystals, 1.9 images/sec.
# 3465 images processed, 3443 hits (99.4%), 1485 indexable (43.1% of hits, 42.9% overall), 1485 crystals, 1.7 images/sec.
# 3477 images processed, 3454 hits (99.3%), 1491 indexable (43.2% of hits, 42.9% overall), 1491 crystals, 2.4 images/sec.
# 3488 images processed, 3465 hits (99.3%), 1496 indexable (43.2% of hits, 42.9% overall), 1496 crystals, 2.1 images/sec.
# 3504 images processed, 3480 hits (99.3%), 1506 indexable (43.3% of hits, 43.0% overall), 1506 crystals, 3.2 images/sec.
# 3515 images processed, 3491 hits (99.3%), 1512 indexable (43.3% of hits, 43.0% overall), 1512 crystals, 2.1 images/sec.
# 3532 images processed, 3508 hits (99.3%), 1517 indexable (43.2% of hits, 43.0% overall), 1517 crystals, 3.3 images/sec.
# WARNING: Radius determination failed
# 3547 images processed, 3522 hits (99.3%), 1522 indexable (43.2% of hits, 42.9% overall), 1522 crystals, 3.0 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3562
# 3561 images processed, 3536 hits (99.3%), 1526 indexable (43.2% of hits, 42.9% overall), 1526 crystals, 2.8 images/sec.
# WARNING: Radius determination failed
# 3577 images processed, 3552 hits (99.3%), 1535 indexable (43.2% of hits, 42.9% overall), 1535 crystals, 3.1 images/sec.
# 3591 images processed, 3566 hits (99.3%), 1541 indexable (43.2% of hits, 42.9% overall), 1541 crystals, 2.6 images/sec.
# 3602 images processed, 3577 hits (99.3%), 1544 indexable (43.2% of hits, 42.9% overall), 1544 crystals, 2.0 images/sec.
# 3612 images processed, 3587 hits (99.3%), 1549 indexable (43.2% of hits, 42.9% overall), 1549 crystals, 2.0 images/sec.
# 3627 images processed, 3602 hits (99.3%), 1553 indexable (43.1% of hits, 42.8% overall), 1553 crystals, 2.9 images/sec.
# 3641 images processed, 3616 hits (99.3%), 1555 indexable (43.0% of hits, 42.7% overall), 1555 crystals, 2.6 images/sec.
# 3655 images processed, 3630 hits (99.3%), 1563 indexable (43.1% of hits, 42.8% overall), 1563 crystals, 2.8 images/sec.
# 3668 images processed, 3643 hits (99.3%), 1565 indexable (43.0% of hits, 42.7% overall), 1565 crystals, 2.5 images/sec.
# 3685 images processed, 3660 hits (99.3%), 1575 indexable (43.0% of hits, 42.7% overall), 1575 crystals, 3.2 images/sec.
# 3699 images processed, 3674 hits (99.3%), 1579 indexable (43.0% of hits, 42.7% overall), 1579 crystals, 2.7 images/sec.
# 3710 images processed, 3685 hits (99.3%), 1583 indexable (43.0% of hits, 42.7% overall), 1583 crystals, 2.2 images/sec.
# 3722 images processed, 3697 hits (99.3%), 1588 indexable (43.0% of hits, 42.7% overall), 1588 crystals, 2.4 images/sec.
# 3739 images processed, 3714 hits (99.3%), 1598 indexable (43.0% of hits, 42.7% overall), 1598 crystals, 3.2 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3739
# 3751 images processed, 3726 hits (99.3%), 1601 indexable (43.0% of hits, 42.7% overall), 1601 crystals, 2.3 images/sec.
# 3766 images processed, 3741 hits (99.3%), 1607 indexable (43.0% of hits, 42.7% overall), 1607 crystals, 2.7 images/sec.
# 3780 images processed, 3755 hits (99.3%), 1615 indexable (43.0% of hits, 42.7% overall), 1615 crystals, 2.8 images/sec.
# 3787 images processed, 3762 hits (99.3%), 1616 indexable (43.0% of hits, 42.7% overall), 1616 crystals, 1.4 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3801
# 3805 images processed, 3780 hits (99.3%), 1622 indexable (42.9% of hits, 42.6% overall), 1622 crystals, 3.5 images/sec.
# WARNING: Radius determination failed
# 3820 images processed, 3795 hits (99.3%), 1630 indexable (43.0% of hits, 42.7% overall), 1630 crystals, 2.9 images/sec.
# 3829 images processed, 3804 hits (99.3%), 1637 indexable (43.0% of hits, 42.8% overall), 1637 crystals, 1.7 images/sec.
# 3846 images processed, 3821 hits (99.3%), 1644 indexable (43.0% of hits, 42.7% overall), 1644 crystals, 3.3 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3853
# WARNING: Radius determination failed
# 3861 images processed, 3836 hits (99.4%), 1649 indexable (43.0% of hits, 42.7% overall), 1649 crystals, 2.9 images/sec.
# 3873 images processed, 3848 hits (99.4%), 1653 indexable (43.0% of hits, 42.7% overall), 1653 crystals, 2.4 images/sec.
# 3884 images processed, 3859 hits (99.4%), 1657 indexable (42.9% of hits, 42.7% overall), 1657 crystals, 2.0 images/sec.
# 3901 images processed, 3876 hits (99.4%), 1662 indexable (42.9% of hits, 42.6% overall), 1662 crystals, 3.2 images/sec.
# 3913 images processed, 3888 hits (99.4%), 1666 indexable (42.8% of hits, 42.6% overall), 1666 crystals, 2.3 images/sec.
# 3924 images processed, 3899 hits (99.4%), 1671 indexable (42.9% of hits, 42.6% overall), 1671 crystals, 2.1 images/sec.
# 3935 images processed, 3909 hits (99.3%), 1673 indexable (42.8% of hits, 42.5% overall), 1673 crystals, 2.1 images/sec.
# 3944 images processed, 3918 hits (99.3%), 1678 indexable (42.8% of hits, 42.5% overall), 1678 crystals, 1.7 images/sec.
# 3954 images processed, 3928 hits (99.3%), 1684 indexable (42.9% of hits, 42.6% overall), 1684 crystals, 1.9 images/sec.
# 3964 images processed, 3938 hits (99.3%), 1686 indexable (42.8% of hits, 42.5% overall), 1686 crystals, 1.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //3979
# 3979 images processed, 3953 hits (99.3%), 1692 indexable (42.8% of hits, 42.5% overall), 1692 crystals, 2.8 images/sec.
# 3996 images processed, 3970 hits (99.3%), 1700 indexable (42.8% of hits, 42.5% overall), 1700 crystals, 3.3 images/sec.
# 4015 images processed, 3989 hits (99.4%), 1708 indexable (42.8% of hits, 42.5% overall), 1708 crystals, 3.8 images/sec.
# 4025 images processed, 3999 hits (99.4%), 1711 indexable (42.8% of hits, 42.5% overall), 1711 crystals, 1.9 images/sec.
# 4037 images processed, 4011 hits (99.4%), 1719 indexable (42.9% of hits, 42.6% overall), 1719 crystals, 2.3 images/sec.
# 4051 images processed, 4025 hits (99.4%), 1727 indexable (42.9% of hits, 42.6% overall), 1727 crystals, 2.6 images/sec.
# 4070 images processed, 4044 hits (99.4%), 1733 indexable (42.9% of hits, 42.6% overall), 1733 crystals, 3.7 images/sec.
# 4083 images processed, 4057 hits (99.4%), 1740 indexable (42.9% of hits, 42.6% overall), 1740 crystals, 2.5 images/sec.
# 4095 images processed, 4068 hits (99.3%), 1742 indexable (42.8% of hits, 42.5% overall), 1742 crystals, 2.4 images/sec.
# 4109 images processed, 4082 hits (99.3%), 1747 indexable (42.8% of hits, 42.5% overall), 1747 crystals, 2.7 images/sec.
# 4121 images processed, 4094 hits (99.3%), 1755 indexable (42.9% of hits, 42.6% overall), 1755 crystals, 2.4 images/sec.
# 4134 images processed, 4107 hits (99.3%), 1763 indexable (42.9% of hits, 42.6% overall), 1763 crystals, 2.5 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4133
# 4151 images processed, 4123 hits (99.3%), 1772 indexable (43.0% of hits, 42.7% overall), 1772 crystals, 3.3 images/sec.
# 4166 images processed, 4138 hits (99.3%), 1781 indexable (43.0% of hits, 42.8% overall), 1781 crystals, 3.0 images/sec.
# 4180 images processed, 4152 hits (99.3%), 1789 indexable (43.1% of hits, 42.8% overall), 1789 crystals, 2.7 images/sec.
# 4191 images processed, 4163 hits (99.3%), 1794 indexable (43.1% of hits, 42.8% overall), 1794 crystals, 2.1 images/sec.
# 4202 images processed, 4174 hits (99.3%), 1798 indexable (43.1% of hits, 42.8% overall), 1798 crystals, 2.2 images/sec.
# 4215 images processed, 4187 hits (99.3%), 1801 indexable (43.0% of hits, 42.7% overall), 1801 crystals, 2.4 images/sec.
# 4231 images processed, 4202 hits (99.3%), 1810 indexable (43.1% of hits, 42.8% overall), 1810 crystals, 3.1 images/sec.
# 4245 images processed, 4216 hits (99.3%), 1816 indexable (43.1% of hits, 42.8% overall), 1816 crystals, 2.6 images/sec.
# 4260 images processed, 4231 hits (99.3%), 1817 indexable (42.9% of hits, 42.7% overall), 1817 crystals, 2.9 images/sec.
# 4271 images processed, 4242 hits (99.3%), 1824 indexable (43.0% of hits, 42.7% overall), 1824 crystals, 2.1 images/sec.
# 4283 images processed, 4254 hits (99.3%), 1828 indexable (43.0% of hits, 42.7% overall), 1828 crystals, 2.2 images/sec.
# 4294 images processed, 4265 hits (99.3%), 1834 indexable (43.0% of hits, 42.7% overall), 1834 crystals, 2.2 images/sec.
# 4309 images processed, 4280 hits (99.3%), 1840 indexable (43.0% of hits, 42.7% overall), 1840 crystals, 2.7 images/sec.
# 4325 images processed, 4295 hits (99.3%), 1845 indexable (43.0% of hits, 42.7% overall), 1845 crystals, 3.1 images/sec.
# 4343 images processed, 4312 hits (99.3%), 1853 indexable (43.0% of hits, 42.7% overall), 1853 crystals, 3.4 images/sec.
# 4357 images processed, 4326 hits (99.3%), 1862 indexable (43.0% of hits, 42.7% overall), 1862 crystals, 2.7 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4368
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4374
# 4370 images processed, 4339 hits (99.3%), 1868 indexable (43.1% of hits, 42.7% overall), 1868 crystals, 2.4 images/sec.
# 4382 images processed, 4351 hits (99.3%), 1874 indexable (43.1% of hits, 42.8% overall), 1874 crystals, 2.3 images/sec.
# 4400 images processed, 4369 hits (99.3%), 1877 indexable (43.0% of hits, 42.7% overall), 1877 crystals, 3.5 images/sec.
# WARNING: 2 implausibly negative reflections in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4399
# 4416 images processed, 4385 hits (99.3%), 1884 indexable (43.0% of hits, 42.7% overall), 1884 crystals, 3.1 images/sec.
# 4428 images processed, 4396 hits (99.3%), 1885 indexable (42.9% of hits, 42.6% overall), 1885 crystals, 2.2 images/sec.
# 4442 images processed, 4410 hits (99.3%), 1897 indexable (43.0% of hits, 42.7% overall), 1897 crystals, 2.7 images/sec.
# 4452 images processed, 4420 hits (99.3%), 1900 indexable (43.0% of hits, 42.7% overall), 1900 crystals, 2.0 images/sec.
# 4468 images processed, 4436 hits (99.3%), 1905 indexable (42.9% of hits, 42.6% overall), 1905 crystals, 3.0 images/sec.
# 4480 images processed, 4448 hits (99.3%), 1910 indexable (42.9% of hits, 42.6% overall), 1910 crystals, 2.3 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4484
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4489
# 4493 images processed, 4461 hits (99.3%), 1916 indexable (43.0% of hits, 42.6% overall), 1916 crystals, 2.5 images/sec.
# 4509 images processed, 4477 hits (99.3%), 1923 indexable (43.0% of hits, 42.6% overall), 1923 crystals, 2.9 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4522
# 4520 images processed, 4488 hits (99.3%), 1928 indexable (43.0% of hits, 42.7% overall), 1928 crystals, 2.2 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4528
# 4533 images processed, 4501 hits (99.3%), 1935 indexable (43.0% of hits, 42.7% overall), 1935 crystals, 2.5 images/sec.
# 4544 images processed, 4512 hits (99.3%), 1939 indexable (43.0% of hits, 42.7% overall), 1939 crystals, 2.2 images/sec.
# 4552 images processed, 4520 hits (99.3%), 1941 indexable (42.9% of hits, 42.6% overall), 1941 crystals, 1.5 images/sec.
# 4562 images processed, 4530 hits (99.3%), 1945 indexable (42.9% of hits, 42.6% overall), 1945 crystals, 1.8 images/sec.
# 4579 images processed, 4546 hits (99.3%), 1958 indexable (43.1% of hits, 42.8% overall), 1958 crystals, 3.2 images/sec.
# 4591 images processed, 4558 hits (99.3%), 1967 indexable (43.2% of hits, 42.8% overall), 1967 crystals, 2.4 images/sec.
# 4605 images processed, 4572 hits (99.3%), 1973 indexable (43.2% of hits, 42.8% overall), 1973 crystals, 2.6 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4608
# 4617 images processed, 4584 hits (99.3%), 1977 indexable (43.1% of hits, 42.8% overall), 1977 crystals, 2.3 images/sec.
# 4628 images processed, 4595 hits (99.3%), 1984 indexable (43.2% of hits, 42.9% overall), 1984 crystals, 2.1 images/sec.
# 4640 images processed, 4607 hits (99.3%), 1989 indexable (43.2% of hits, 42.9% overall), 1989 crystals, 2.3 images/sec.
# 4648 images processed, 4615 hits (99.3%), 1991 indexable (43.1% of hits, 42.8% overall), 1991 crystals, 1.6 images/sec.
# WARNING: Radius determination failed
# 4661 images processed, 4628 hits (99.3%), 1995 indexable (43.1% of hits, 42.8% overall), 1995 crystals, 2.5 images/sec.
# 4672 images processed, 4639 hits (99.3%), 2002 indexable (43.2% of hits, 42.9% overall), 2002 crystals, 2.1 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4684
# 4687 images processed, 4654 hits (99.3%), 2009 indexable (43.2% of hits, 42.9% overall), 2009 crystals, 3.0 images/sec.
# 4698 images processed, 4664 hits (99.3%), 2013 indexable (43.2% of hits, 42.8% overall), 2013 crystals, 2.2 images/sec.
# 4708 images processed, 4674 hits (99.3%), 2019 indexable (43.2% of hits, 42.9% overall), 2019 crystals, 2.0 images/sec.
# WARNING: Radius determination failed
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4707
# 4720 images processed, 4686 hits (99.3%), 2024 indexable (43.2% of hits, 42.9% overall), 2024 crystals, 2.2 images/sec.
# 4729 images processed, 4695 hits (99.3%), 2030 indexable (43.2% of hits, 42.9% overall), 2030 crystals, 1.7 images/sec.
# 4742 images processed, 4708 hits (99.3%), 2036 indexable (43.2% of hits, 42.9% overall), 2036 crystals, 2.4 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4746
# WARNING: Radius determination failed
# 4751 images processed, 4717 hits (99.3%), 2040 indexable (43.2% of hits, 42.9% overall), 2040 crystals, 1.8 images/sec.
# 4763 images processed, 4729 hits (99.3%), 2047 indexable (43.3% of hits, 43.0% overall), 2047 crystals, 2.4 images/sec.
# 4773 images processed, 4739 hits (99.3%), 2051 indexable (43.3% of hits, 43.0% overall), 2051 crystals, 1.9 images/sec.
# 4780 images processed, 4746 hits (99.3%), 2054 indexable (43.3% of hits, 43.0% overall), 2054 crystals, 1.4 images/sec.
# 4789 images processed, 4755 hits (99.3%), 2059 indexable (43.3% of hits, 43.0% overall), 2059 crystals, 1.8 images/sec.
# 4798 images processed, 4764 hits (99.3%), 2062 indexable (43.3% of hits, 43.0% overall), 2062 crystals, 1.7 images/sec.
# 4804 images processed, 4770 hits (99.3%), 2065 indexable (43.3% of hits, 43.0% overall), 2065 crystals, 1.1 images/sec.
# 4817 images processed, 4783 hits (99.3%), 2070 indexable (43.3% of hits, 43.0% overall), 2070 crystals, 2.6 images/sec.
# 4835 images processed, 4801 hits (99.3%), 2078 indexable (43.3% of hits, 43.0% overall), 2078 crystals, 3.4 images/sec.
# 4850 images processed, 4816 hits (99.3%), 2086 indexable (43.3% of hits, 43.0% overall), 2086 crystals, 3.0 images/sec.
# 4859 images processed, 4825 hits (99.3%), 2090 indexable (43.3% of hits, 43.0% overall), 2090 crystals, 1.8 images/sec.
# 4866 images processed, 4832 hits (99.3%), 2096 indexable (43.4% of hits, 43.1% overall), 2096 crystals, 1.4 images/sec.
# WARNING: Radius determination failed
# 4879 images processed, 4845 hits (99.3%), 2101 indexable (43.4% of hits, 43.1% overall), 2101 crystals, 2.6 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //4872
# 4892 images processed, 4858 hits (99.3%), 2109 indexable (43.4% of hits, 43.1% overall), 2109 crystals, 2.6 images/sec.
# 4901 images processed, 4867 hits (99.3%), 2110 indexable (43.4% of hits, 43.1% overall), 2110 crystals, 1.8 images/sec.
# 4914 images processed, 4880 hits (99.3%), 2114 indexable (43.3% of hits, 43.0% overall), 2114 crystals, 2.5 images/sec.
# 4925 images processed, 4891 hits (99.3%), 2122 indexable (43.4% of hits, 43.1% overall), 2122 crystals, 2.2 images/sec.
# WARNING: Radius determination failed
# 4939 images processed, 4905 hits (99.3%), 2129 indexable (43.4% of hits, 43.1% overall), 2129 crystals, 2.7 images/sec.
# 4960 images processed, 4926 hits (99.3%), 2140 indexable (43.4% of hits, 43.1% overall), 2140 crystals, 4.0 images/sec.
# 4968 images processed, 4934 hits (99.3%), 2144 indexable (43.5% of hits, 43.2% overall), 2144 crystals, 1.6 images/sec.
# WARNING: Radius determination failed
# 4980 images processed, 4946 hits (99.3%), 2149 indexable (43.4% of hits, 43.2% overall), 2149 crystals, 2.2 images/sec.
# 4992 images processed, 4957 hits (99.3%), 2154 indexable (43.5% of hits, 43.1% overall), 2154 crystals, 2.2 images/sec.
# 5004 images processed, 4969 hits (99.3%), 2161 indexable (43.5% of hits, 43.2% overall), 2161 crystals, 2.3 images/sec.
# WARNING: 1 implausibly negative reflection in /Users/xiaodong/Desktop/UOX-data/UOX1/deiced_UOX1_min_15_peak.h5 //5014
# 5019 images processed, 4983 hits (99.3%), 2172 indexable (43.6% of hits, 43.3% overall), 2172 crystals, 2.8 images/sec.
# 5028 images processed, 4992 hits (99.3%), 2177 indexable (43.6% of hits, 43.3% overall), 2177 crystals, 1.7 images/sec.
# 5043 images processed, 5007 hits (99.3%), 2185 indexable (43.6% of hits, 43.3% overall), 2185 crystals, 3.0 images/sec.
# 5056 images processed, 5019 hits (99.3%), 2191 indexable (43.7% of hits, 43.3% overall), 2191 crystals, 2.6 images/sec.
# 5074 images processed, 5037 hits (99.3%), 2195 indexable (43.6% of hits, 43.3% overall), 2195 crystals, 3.4 images/sec.
# 5084 images processed, 5047 hits (99.3%), 2197 indexable (43.5% of hits, 43.2% overall), 2197 crystals, 2.0 images/sec.
# 5092 images processed, 5055 hits (99.3%), 2201 indexable (43.5% of hits, 43.2% overall), 2201 crystals, 1.6 images/sec.
# 5098 images processed, 5061 hits (99.3%), 2204 indexable (43.5% of hits, 43.2% overall), 2204 crystals, 1.1 images/sec.
# 5113 images processed, 5076 hits (99.3%), 2210 indexable (43.5% of hits, 43.2% overall), 2210 crystals, 2.8 images/sec.
# 5120 images processed, 5083 hits (99.3%), 2214 indexable (43.6% of hits, 43.2% overall), 2214 crystals, 1.4 images/sec.
# 5128 images processed, 5091 hits (99.3%), 2218 indexable (43.6% of hits, 43.3% overall), 2218 crystals, 1.5 images/sec.
# WARNING: Radius determination failed
# 5140 images processed, 5103 hits (99.3%), 2224 indexable (43.6% of hits, 43.3% overall), 2224 crystals, 2.3 images/sec.
# 5148 images processed, 5111 hits (99.3%), 2230 indexable (43.6% of hits, 43.3% overall), 2230 crystals, 1.5 images/sec.
# 5162 images processed, 5124 hits (99.3%), 2236 indexable (43.6% of hits, 43.3% overall), 2236 crystals, 2.8 images/sec.
# 5178 images processed, 5139 hits (99.2%), 2247 indexable (43.7% of hits, 43.4% overall), 2247 crystals, 3.2 images/sec.
# 5185 images processed, 5146 hits (99.2%), 2251 indexable (43.7% of hits, 43.4% overall), 2251 crystals, 1.3 images/sec.
# 5197 images processed, 5158 hits (99.2%), 2256 indexable (43.7% of hits, 43.4% overall), 2256 crystals, 2.3 images/sec.
# 5206 images processed, 5167 hits (99.3%), 2260 indexable (43.7% of hits, 43.4% overall), 2260 crystals, 1.8 images/sec.
# 5219 images processed, 5180 hits (99.3%), 2268 indexable (43.8% of hits, 43.5% overall), 2268 crystals, 2.4 images/sec.
# 5231 images processed, 5192 hits (99.3%), 2277 indexable (43.9% of hits, 43.5% overall), 2277 crystals, 2.4 images/sec.
# 5242 images processed, 5203 hits (99.3%), 2282 indexable (43.9% of hits, 43.5% overall), 2282 crystals, 2.1 images/sec.
# 5251 images processed, 5212 hits (99.3%), 2286 indexable (43.9% of hits, 43.5% overall), 2286 crystals, 1.7 images/sec.
# 5266 images processed, 5227 hits (99.3%), 2293 indexable (43.9% of hits, 43.5% overall), 2293 crystals, 2.9 images/sec.
# 5281 images processed, 5242 hits (99.3%), 2300 indexable (43.9% of hits, 43.6% overall), 2300 crystals, 2.9 images/sec.
# 5287 images processed, 5248 hits (99.3%), 2301 indexable (43.8% of hits, 43.5% overall), 2301 crystals, 1.1 images/sec.
# 5303 images processed, 5264 hits (99.3%), 2313 indexable (43.9% of hits, 43.6% overall), 2313 crystals, 3.1 images/sec.
# 5320 images processed, 5281 hits (99.3%), 2321 indexable (44.0% of hits, 43.6% overall), 2321 crystals, 3.3 images/sec.
# 5330 images processed, 5291 hits (99.3%), 2325 indexable (43.9% of hits, 43.6% overall), 2325 crystals, 2.0 images/sec.
# 5342 images processed, 5303 hits (99.3%), 2328 indexable (43.9% of hits, 43.6% overall), 2328 crystals, 2.3 images/sec.
# 5352 images processed, 5313 hits (99.3%), 2332 indexable (43.9% of hits, 43.6% overall), 2332 crystals, 2.0 images/sec.
# Waiting for the last patterns to be processed...
# Final: 5362 images processed, 5323 hits (99.3%), 2337 indexable (43.9% of hits, 43.6% overall), 2337 crystals.
# Processing XY pairs: 100%|██████████| 1/1 [37:08<00:00, 2228.41s/it]
