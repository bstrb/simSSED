# %%
# FASTER AND CHUNKED WITH CHUNK-WISE CSV SAVING

import os
import h5py
import numpy as np
import pandas as pd
from multiprocessing import Pool
from find_diffraction_center import find_diffraction_center

# Define your image and mask file paths
image_file = "/home/bubl3932/files/UOX1/UOX1_original_IQM/UOX1.h5"
mask_file = "/home/bubl3932/mask/pxmask.h5"

def process_image(args):
    frame_number, image = args
    center = find_diffraction_center(
        image,
        masks,
        threshold=threshold,
        max_iters=max_iters,
        step_size=step_size,
        n_steps=n_steps,
        n_wedges=n_wedges,
        n_rad_bins=n_rad_bins,
        plot_profiles=plot_profiles,
        frame_number=frame_number
    )
    return frame_number, center

# Define parameters
threshold = 0.1
max_iters = 10
step_size = 1
n_steps = 5
n_wedges = 4
n_rad_bins = 100
plot_profiles = False

chunk_size = 100  # Adjust based on available memory
csv_file = os.path.join(os.path.dirname(image_file),"centers.csv")

# Remove existing CSV file if present
if os.path.exists(csv_file):
    os.remove(csv_file)
header_written = False

with h5py.File(image_file, 'r') as f_img, h5py.File(mask_file, 'r') as f_mask:
    # Adjust dataset names to those in your HDF5 files
    dataset_images = f_img['/entry/data/images']
    masks = f_mask['/mask'][:].astype(bool)  # load the mask entirely if it's small enough

    n_images = dataset_images.shape[0]
    print(f"Total images: {n_images}")

    for i in range(0, n_images, chunk_size):
        # Read a chunk of images and convert them to float32
        images_chunk = dataset_images[i:i+chunk_size].astype(np.float32)
        # Create list of tuples: (frame_number, image)
        args = [(i + idx, img) for idx, img in enumerate(images_chunk)]
        
        # Process the current chunk using multiprocessing
        with Pool() as pool:
            centers = pool.map(process_image, args)
        
        # Create a DataFrame for this chunk
        df_chunk = pd.DataFrame(centers, columns=["frame_number", "center"])
        df_chunk[['center_x', 'center_y']] = pd.DataFrame(df_chunk['center'].tolist(), index=df_chunk.index)
        df_chunk = df_chunk.drop(columns=["center"])
        
        # Save the current chunk to CSV in append mode (write header only for the first chunk)
        if not header_written:
            df_chunk.to_csv(csv_file, index=False, mode='w')
            header_written = True
        else:
            df_chunk.to_csv(csv_file, index=False, mode='a', header=False)
        
        print(f"Processed images {i} to {min(i+chunk_size, n_images)}")

print("Finished processing and saved centers to", csv_file)
# Out:
# Total images: 27025
# Frame 42: Convergence reached with center found (639.1504535502033, 5947.113934939005).
# Frame 38: Convergence reached with center found (550.8118896925859, -4407.283996383363).
# Frame 40: Convergence reached with center found (591.076351580272, 1284.7985576690382).
# Frame 44: Convergence reached with center found (1220.8202890944476, 2109.5328238098364).
# Frame 2: Convergence reached with center found (701.3522746201035, 1228.5320074432593).
# Frame 28: Convergence reached with center found (677.3694888863673, 1134.8312436173835).
# Frame 24: Convergence reached with center found (334.43094050743656, -164.57357392825898).
# Frame 32: Convergence reached with center found (541.6629018383725, 668.7007739885559).
# Frame 10: Convergence reached with center found (545.4818295103632, 768.9169079599466).
# Frame 0: Convergence reached with center found (478.0207882423268, 738.437138498959).
# Frame 34: Convergence reached with center found (581.5671387001387, 673.6801794996065).
# Frame 26: Convergence reached with center found (576.5159960515563, 691.9536907430032).
# Frame 6: Convergence reached with center found (742.739500774752, 671.1101038345771).
# Frame 8: Convergence reached with center found (576.3685328449403, 727.1487508992715).
# Frame 12: Convergence reached with center found (563.8695521858133, 766.9628746730673).
# Frame 43: Convergence reached with center found (403.4823583201374, -482.28085621250307).
# Frame 20: Convergence reached with center found (515.2835146448818, 752.2019387079295).
# Frame 22: Convergence reached with center found (531.296273827534, 749.5976732223903).
# Frame 16: Convergence reached with center found (544.6987624782714, 751.1927526243356).
# Frame 30: Convergence reached with center found (586.3136386790692, 754.2243373238762).
# Frame 41: Convergence reached with center found (396.49327812631935, -554.7874925003889).
# Frame 14: Convergence reached with center found (527.6683672921388, 903.1042436870993).
# Frame 39: Convergence reached with center found (443.05549910642225, -22.904372766055573).
# Frame 46: Convergence reached with center found (607.5241502683364, 911.3943524091998).
# Frame 33: Convergence reached with center found (569.970352743627, 1057.7624776248233).
# Frame 3: Convergence reached with center found (590.1801399980508, 1090.7241201391955).
# Frame 27: Convergence reached with center found (842.6192732523288, 1245.2759941826826).
# Frame 29: Convergence reached with center found (750.0176718498006, 1392.3552855795272).
# Frame 9: Convergence reached with center found (768.9799669468428, 1236.65378987185).
# Frame 25: Convergence reached with center found (236.95179767994813, -287.69051195220226).
# Frame 23: Convergence reached with center found (618.9101456346206, 1344.9752591905935).
# Frame 31: Convergence reached with center found (645.6308863364471, 1461.7663813248867).
# Frame 36: Convergence reached with center found (483.2689865733609, 338.4268799484111).
# Frame 11: Convergence reached with center found (544.7883744295667, 663.8351086405379).
# Frame 52: Convergence reached with center found (559.5287856274483, 2085.9058219640688).
# Frame 15: Convergence reached with center found (948.1577672969217, 1157.5844668098428).
# Frame 4: Convergence reached with center found (428.11448383280845, 82.06757388818629).
# Frame 47: Convergence reached with center found (268.5911349889601, -955.6667889327608).
# Frame 13: Convergence reached with center found (481.7339930043156, 789.4121264724578).
# Frame 17: Convergence reached with center found (528.6494290680411, 580.647936356577).
# Frame 54: Convergence reached with center found (446.424925204274, 1322.3393287240729).
# Frame 21: Convergence reached with center found (509.0897411318172, 822.9192938943802).
# Frame 50: Convergence reached with center found (499.518458811663, 246.16286140732404).
# Frame 56: Convergence reached with center found (412.1673765292252, -546.0091583597643).
# Frame 62: Convergence reached with center found (509.3749993917837, 1074.4628769116237).
# Frame 64: Convergence reached with center found (547.6407442315077, 1989.7568890285195).
# Frame 66: Convergence reached with center found (562.8418307210031, 1145.9076112852665).
# Frame 45: Convergence reached with center found (444.94500967196973, 321.36648446964483).
# Frame 5: Convergence reached with center found (697.0817003291068, 1536.998321054478).
# Frame 37: Convergence reached with center found (282.91354013616706, -1403.1862260207354).
# Frame 53: Convergence reached with center found (427.1146208471267, 1256.7259687650146).
# Frame 18: Convergence reached with center found (528.0306294129407, 785.6190173748896).
# Frame 55: Convergence reached with center found (529.6396499925278, -151.6773767991219).
# Frame 48: Convergence reached with center found (444.91350983968374, 168.01034581241785).
# Frame 51: Convergence reached with center found (449.8290385745056, 1736.4553651850401).
# Frame 57: Convergence reached with center found (454.6840259897616, 1163.8498962529914).
# Frame 63: Convergence reached with center found (8.200747487858917, 4744.637065550657).
# Frame 72: Convergence reached with center found (505.9617737363665, 506.54803072392826).
# Frame 58: Convergence reached with center found (424.33056246769326, 687.4592003558248).
# Frame 1: Convergence reached with center found (468.679768065768, 281.91733440611586).
# Frame 7: Convergence reached with center found (733.415598257711, 788.9818614172259).
# Frame 65: Convergence reached with center found (471.2948910766492, 1252.2627013297933).
# Frame 60: Convergence reached with center found (499.99674910019735, 983.5338054878284).
# Frame 80: Convergence reached with center found (515.4887078523775, 508.5621239815432).
# Frame 68: Convergence reached with center found (448.8538456503639, 763.5805661810482).
# Frame 82: Convergence reached with center found (515.5124838591934, 508.8953706549036).
# Frame 73: Convergence reached with center found (510.33829061595003, 514.1729505501044).
# Frame 59: Convergence reached with center found (219.2271850583535, 1906.348330086005).
# Frame 76: Convergence reached with center found (515.896789149464, 508.92620199578863).
# Frame 90: Convergence reached with center found (515.6928498641955, 508.6702416115923).
# Frame 70: Convergence reached with center found (464.6055594773919, 511.62839797657625).
# Frame 61: Convergence reached with center found (454.142987552003, 756.7522449420298).
# Frame 84: Convergence reached with center found (515.4848482250679, 508.42731331537624).
# Frame 49: Convergence reached with center found (480.47230608434535, 231.17518177317427).
# Frame 98: Convergence reached with center found (515.3356499596262, 508.84425571871185).
# Frame 19: Convergence reached with center found (523.5613637530232, 951.2955563137665).
# Frame 88: Convergence reached with center found (515.8094960000452, 508.7392778651881).
# Frame 92: Convergence reached with center found (516.1576707376385, 509.10648789083416).
# Frame 94: Convergence reached with center found (515.6543215045014, 508.5707817287715).
# Frame 69: Convergence reached with center found (424.27025117177715, 737.9523596550861).
# Frame 67: Convergence reached with center found (467.67140562809857, 912.7851965644858).
# Frame 74: Convergence reached with center found (517.0454176438532, 505.40052167297034).
# Frame 78: Convergence reached with center found (515.3202976346555, 508.7122608391138).
# Frame 71: Convergence reached with center found (495.8167448328527, 471.5967774553442).
# Frame 91: Convergence reached with center found (515.4923890083194, 508.6794788420012).
# Frame 86: Convergence reached with center found (515.7070019323476, 509.0092840164216).
# Frame 35: Convergence reached with center found (428.5147811595474, 127.28054381194633).
# Frame 96: Convergence reached with center found (515.4124755781621, 508.38170977101856).
# Frame 77: Convergence reached with center found (515.6086625667855, 508.2694967331322).
# Frame 81: Convergence reached with center found (515.3458167016977, 508.8264956282792).
# Frame 85: Convergence reached with center found (515.6038827667741, 509.2797401358414).
# Frame 89: Convergence reached with center found (515.7217362906864, 508.3746014853199).
# Frame 79: Convergence reached with center found (515.5254266467479, 508.79424790647346).
# Frame 83: Convergence reached with center found (515.196080974798, 508.78020246246604).
# Frame 97: Convergence reached with center found (515.4025652280416, 508.3332281514704).
# Frame 99: Convergence reached with center found (515.1512345647358, 508.94316622907775).
# Frame 75: Convergence reached with center found (515.8339831233357, 508.7290265281237).
# Frame 95: Convergence reached with center found (515.1885702486009, 508.3770294005592).
# Frame 93: Convergence reached with center found (515.7608031438253, 508.36448160259624).
# Frame 87: Convergence reached with center found (515.4013368936525, 508.6643540693383).
# Processed images 0 to 100
# Frame 128: Convergence reached with center found (515.565160606666, 508.1763310599981).
# Frame 142: Convergence reached with center found (515.4849902915852, 508.4473581325688).
# Frame 114: Convergence reached with center found (515.2717186656349, 508.38334940033076).
# Frame 118: Convergence reached with center found (515.6250397177869, 508.3364879648498).
# Frame 116: Convergence reached with center found (515.6458395802476, 509.03548186961973).
# Frame 138: Convergence reached with center found (515.0510656280107, 508.8738047900116).
# Frame 144: Convergence reached with center found (515.6565454912302, 508.8551997711238).
# Frame 112: Convergence reached with center found (515.3773901259002, 508.30222177719196).
# Frame 140: Convergence reached with center found (515.4808448265628, 508.6237681140408).
# Frame 126: Convergence reached with center found (515.2046039193322, 508.21560346968624).
# Frame 100: Convergence reached with center found (515.0238237255589, 508.2688907564475).
# Frame 136: Convergence reached with center found (515.3587433622843, 508.01534654291237).
# Frame 106: Convergence reached with center found (515.3290491477431, 508.3713312371117).
# Frame 110: Convergence reached with center found (515.7609846364121, 508.5810792440518).
# Frame 129: Convergence reached with center found (515.1067373144244, 509.3571317782532).
# Frame 139: Convergence reached with center found (515.4241039211225, 508.18617642623263).
# Frame 115: Convergence reached with center found (515.5551483440967, 508.28957816038354).
# Frame 122: Convergence reached with center found (515.5051620690589, 508.5003830861988).
# Frame 102: Convergence reached with center found (515.4056843522733, 508.6032141047042).
# Frame 134: Convergence reached with center found (515.1608710037706, 508.4975862252297).
# Frame 124: Convergence reached with center found (515.5716039828762, 508.4106576892856).
# Frame 107: Convergence reached with center found (515.0853659723729, 508.59299563552054).
# Frame 113: Convergence reached with center found (515.3865827740486, 508.1100653409774).
# Frame 146: Convergence reached with center found (515.1832238923638, 508.1912013027695).
# Frame 103: Convergence reached with center found (515.3094989702603, 508.59674585691715).
# Frame 141: Convergence reached with center found (515.5833352754487, 508.143694224548).
# Frame 137: Convergence reached with center found (515.3668427274371, 508.4245294421511).
# Frame 117: Convergence reached with center found (515.317217949773, 508.5825478257077).
# Frame 127: Convergence reached with center found (515.1926660378407, 508.384224564107).
# Frame 120: Convergence reached with center found (515.8479763010712, 508.3835327186041).
# Frame 125: Convergence reached with center found (515.0267174016004, 508.25745860704774).
# Frame 108: Convergence reached with center found (515.6056492723499, 508.436674878855).

# %%
# Plotting
# %matplotlib qt
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider

# Determine if there are multiple images.
if images.ndim == 3:
    n_images = images.shape[0]
else:
    n_images = 1

# Create the figure and axis.
fig, ax = plt.subplots(figsize=(8, 8))
plt.subplots_adjust(bottom=0.25)  # leave space at the bottom for the slider

# Initial image index.
init_index = 0

# Display the initial image.
if n_images > 1:
    im_handle = ax.imshow(images[init_index], cmap='gray', origin='lower')
    refined_center = centers[init_index]
else:
    im_handle = ax.imshow(images, cmap='gray', origin='lower')
    refined_center = center  # single image case

# Plot the refined center marker.
center_handle, = ax.plot(refined_center[1], refined_center[0], 'ro', markersize=10, label='Refined Center')
ax.set_title('Diffraction Image with Refined Center')
ax.set_xlabel('Column (pixels)')
ax.set_ylabel('Row (pixels)')
ax.legend()

# Create a slider axis below the image.
ax_slider = plt.axes([0.2, 0.1, 0.65, 0.03])
slider = Slider(ax_slider, 'Image Index', 0, n_images - 1, valinit=init_index, valstep=1)

# Update function to be called whenever the slider value changes.
def update(val):
    idx = int(slider.val)
    # Update image.
    if n_images > 1:
        im_handle.set_data(images[idx])
        refined_center = centers[idx]
    else:
        refined_center = center
    # Update center marker.
    center_handle.set_data(refined_center[1], refined_center[0])
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()

# %%
import matplotlib.pyplot as plt

# For a single image case (or for example, the first image in the stack):
plt.figure(figsize=(8, 8))
plt.imshow(images[0] if images.ndim == 3 else images, cmap='gray', origin='lower')
# Note: best_center is either 'center' or centers[0] if multiple images were processed.
refined_center = centers[0] if images.ndim == 3 else center
plt.plot(refined_center[1], refined_center[0], 'ro', markersize=10, label='Refined Center')
plt.title('Diffraction Image with Refined Center')
plt.xlabel('Column (pixels)')
plt.ylabel('Row (pixels)')
plt.legend()
plt.show()
